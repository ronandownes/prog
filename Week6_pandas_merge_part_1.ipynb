# %% [markdown]
# # Start at 19:50

# %%
class Car:
    make = "Ford"
    def __init__(self, name):
        self.name = name

# %%
car1 = Car("ford1")

# %%
ford1 = car1

# %%
del car1

# %%
ford1.make
# Out:
# 'Ford'

# %% [markdown]
# # Merge

# %%
import pandas as pd

# %%
climate_temp = pd.read_csv("climate_temp.csv")
climate_precip = pd.read_csv("climate_precip.csv")

# %%
climate_temp.head()
# Out:
#              STATION            STATION_NAME ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  DLY-CLDD-BASE72  \
# ...

# %%
climate_precip.head(50)
# Out:
#               STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
# 5   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100106            -6.66
# 6   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100107            -6.66
# 7   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100108            -6.66
# 8   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100109            -6.66
# 9   GHCND:USC00049099  TWENTYNINE PALMS CA US  20100110            -6.66
# 10  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100111            -6.66
# 11  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100112            -6.66
# ...

# %%
climate_temp.shape
# Out:
# (127020, 21)

# %%
climate_precip.shape
# Out:
# (151110, 29)

# %%
precipStation1 = climate_precip[climate_precip["STATION"] ==  "GHCND:USC00049099"]

# %%
innerMerge = pd.merge(precipStation1, climate_temp)

# %%
innerMerge.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
print(climate_temp.shape)
print(precipStation1.shape)
print(innerMerge.shape)
# Out:
# (127020, 21)
# (365, 29)
# (365, 47)

# %%
outer_merge = pd.merge(precipStation1, climate_temp, how="outer", on=["STATION", "DATE"])

# %%
outer_merge.head()
# Out:
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0           -666.0            -66.6            -6.66           -666.0
# 1           -666.0            -66.6            -6.66           -666.0
# 2           -666.0            -66.6            -6.66           -666.0
# 3          -9999.0          -9999.0            -6.66          -9999.0
# 4          -9999.0          -9999.0            -6.66          -9999.0
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
outer_merge.shape
# Out:
# (127020, 48)

# %%
outer_merge.head(367)
# Out:
#                STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0    GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1    GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2    GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3    GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4    GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
# ..                 ...                     ...       ...              ...
# 362  GHCND:USC00049099  TWENTYNINE PALMS CA US  20101229            -6.66
# 363  GHCND:USC00049099  TWENTYNINE PALMS CA US  20101230            -6.66
# 364  GHCND:USC00049099  TWENTYNINE PALMS CA US  20101231            -6.66
# 365  GHCND:USC00041244                     NaN  20100101              NaN
# 366  GHCND:USC00041244                     NaN  20100102              NaN
#
#      DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# ...

# %%
left_merge = pd.merge(precipStation1, climate_temp, how="left", on=["STATION", "DATE"])

# %%
left_merge.shape
# Out:
# (365, 48)

# %%
precipStation1.shape
# Out:
# (365, 29)

# %%
left_merge.head()
# Out:
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
inner_merge2 = pd.merge(precipStation1, climate_temp, how="inner", on=["STATION", "DATE"])

# %%
inner_merge2.shape
# Out:
# (365, 48)

# %%
inner_merge2["STATION_NAME_x"]
# Out:
# 0      TWENTYNINE PALMS CA US
# 1      TWENTYNINE PALMS CA US
# 2      TWENTYNINE PALMS CA US
# 3      TWENTYNINE PALMS CA US
# 4      TWENTYNINE PALMS CA US
#                 ...
# 360    TWENTYNINE PALMS CA US
# 361    TWENTYNINE PALMS CA US
# 362    TWENTYNINE PALMS CA US
# 363    TWENTYNINE PALMS CA US
# 364    TWENTYNINE PALMS CA US
# Name: STATION_NAME_x, Length: 365, dtype: object
