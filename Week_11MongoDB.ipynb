# %%
#!pip install pymongo

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
# This is the database (document) name
db = client["test"]

# %%
# A document isn't created until at least one collection is.
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
# This is the table (collection) name
coll = db["testCollection"]

# %%
# The collection isn't created until data is inserted
db.list_collection_names()
# Out:
# []

# %%
# MongoDB data takes the form of nested dictionarie or JSON objects
testDict = {"name": "Sam", "Student Number": 42}

# %%
res = coll.insert_one(testDict)

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'test']

# %%
db.list_collection_names()
# Out:
# ['testCollection']

# %%
# If the id (_id) is not specified, it is automatically created.
# These ids have to be unique.
res.inserted_id
# Out:
# ObjectId('6384b286a027f26e0334ff13')

# %%
# Will give an error, since we're trying to add the same object.
# It was automatically given the same id number

#testDict = {"name": "Sam", "Student Number": 42}

# %%
testDict = {"name": "Sam", "Student Number": 42, "_id": 9}

# %%
res = coll.insert_one(testDict)

# %%
res.inserted_id
# Out:
# 9

# %%
testDict2 = [
    {"name": "Sean", "Student Number" : 12},
    {"name": "Jessica", "Student Number" : 23},
    {"name": "Mary", "Student Number" : 24},
    {"name": "Naima", "Student Number" : 25},
    {"name": "Caoilfhionn", "Student Number" : 26},
    {"name": "Muhammad", "Student Number" : 27},
    {"name": "David", "Student Number" : 28},
    
]

# %%
# Will give an error: we are adding more than one!
#res = coll.insert_one(testDict2)

# %%
res = coll.insert_many(testDict2)

# %%
res

# %%
res.inserted_ids
# Out:
# [ObjectId('6384b287a027f26e0334ff14'),
#  ObjectId('6384b287a027f26e0334ff15'),
#  ObjectId('6384b287a027f26e0334ff16'),
#  ObjectId('6384b287a027f26e0334ff17'),
#  ObjectId('6384b287a027f26e0334ff18'),
#  ObjectId('6384b287a027f26e0334ff19'),
#  ObjectId('6384b287a027f26e0334ff1a')]

# %%
# Leave empty to get all rows
res = coll.find()

# Equivilant calls:
#res = coll.find({})
#res = coll.find({},{})

# %%
# Use a dictionary to select only some rows
res = coll.find({"name": "Sam"})

# %%
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6384b286a027f26e0334ff13'), 'name': 'Sam', 'Student Number': 42}
# {'_id': 9, 'name': 'Sam', 'Student Number': 42}

# %%
# The second dictionary specifies the fields (columns) to return
res = coll.find({"name": "Sam"}, {"name": 0})
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6384b286a027f26e0334ff13'), 'Student Number': 42}
# {'_id': 9, 'Student Number': 42}

# %% [markdown]
# 1 means True: mongo will return only those columns
#
# 0 means false: mongo will return everything **except** those columns
#
# Can only have **either** 1s or 0s
#
# Exception: \_id can be different, as it will always be returned unless set to 0

# %%
res = coll.find({"name": "Sam"}, {"name": 1, "_id": 0})
for i in res:
    print(i)
# Out:
# {'name': 'Sam'}
# {'name': 'Sam'}

# %%
res = coll.find({
    "name": {"$gt": "A", "$lt": "M"} 
})
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6384b287a027f26e0334ff15'), 'name': 'Jessica', 'Student Number': 23}
# {'_id': ObjectId('6384b287a027f26e0334ff18'), 'name': 'Caoilfhionn', 'Student Number': 26}
# {'_id': ObjectId('6384b287a027f26e0334ff1a'), 'name': 'David', 'Student Number': 28}

# %%
res = coll.find({
    "name": {"$regex": "a$"} 
})
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6384b287a027f26e0334ff15'), 'name': 'Jessica', 'Student Number': 23}
# {'_id': ObjectId('6384b287a027f26e0334ff17'), 'name': 'Naima', 'Student Number': 25}

# %% [markdown]
# # Using Actual Data
#
# Tweets about the recent US midterm elections
#
# Source: I left a Tweet Stream running for a few hours (will show how later, hopefully!)

# %%
import json

# %%
# Change to where you have the file stored
with open(r"C:\Users\sweis\Downloads\Midterms Tweets\Midterms Tweets.json", encoding="utf8") as f:
    tweets = json.load(f)

# %%
tweets['0']
# Out:
# {'data': {'edit_history_tweet_ids': ['1590047656314691584'],
#   'id': '1590047656314691584',
#   'text': 'RT @CologeroGetz: Arizona! Here are some important names to remember and pictures to share on your social media today!\n\nAbe Hamadeh for Att…'},
#  'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]}

# %%
db = client["MidtermTweets"]

# %%
coll = db["MidtermTweets1"]

# %%
# Will give an error, since the document size would be too big
#coll.insert_many([tweets])

# %%
tweets
# Out:
# {'0': {'data': {'edit_history_tweet_ids': ['1590047656314691584'],
#    'id': '1590047656314691584',
#    'text': 'RT @CologeroGetz: Arizona! Here are some important names to remember and pictures to share on your social media today!\n\nAbe Hamadeh for Att…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '1': {'data': {'edit_history_tweet_ids': ['1590047663289823234'],
#    'id': '1590047663289823234',
#    'text': 'RT @ardenthistorian: Wahltag, das Signal für diverses "was kümmerst du dich um die USA kümmer dich lieber um Deutschland" Gepöbele. Sweet p…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '2': {'data': {'edit_history_tweet_ids': ['1590047663453519872'],
#    'id': '1590047663453519872',
#    'text': '🇺🇸 #Midterms : les Américains aux urnes, entre «peur pour la démocratie» et envie de «sauver» le pays \n\nIls sont des dizaines de millions à avoir attendu le jour J pour exprimer leur choix. Reportage @fredericautran &amp; @juliengester ⤵\nhttps://t.co/5nHxcz63yP'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '3': {'data': {'edit_history_tweet_ids': ['1590047664179408896'],
#    'id': '1590047664179408896',
#    'text': "RT @mattdizwhitlock: Still blown away by Biden's closing message the final week before midterms.\n\nNov 2 - John Kerry says Biden is going to…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '4': {'data': {'edit_history_tweet_ids': ['1590047658911371264'],
#    'id': '1590047658911371264',
#    'text': 'RT @DaoKwonDo: SET THOSE REMINDERS!! \n——\nJoin us for the best audio experience on web3 twitter 🎤 \n——\nDiscussing:\n•Current market analysis/M…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '5': {'data': {'edit_history_tweet_ids': ['1590047662489104384'],
#    'id': '1590047662489104384',
#    'text': 'RT @jerome_riviere: Après un premier entretien ce matin, je serai en compagnie de Steve Bannon pour suivre les résultats des #Midterms amér…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '6': {'data': {'edit_history_tweet_ids': ['1590047668151193601'],
#    'id': '1590047668151193601',
#    'text': 'RT @DebatF24: 🇺🇸🗳️ #Midterms : un test pour la démocratie ?\n\nMais que sont exactement ces élections de mi-mandat ? Comment fonctionnent-elles ? On fait le point dans le @DebatF24 avec @nabia_makhloufi #MidTerms2022 ⤵️ https://t.co/J2HRzlj1pb'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '7': {'data': {'edit_history_tweet_ids': ['1590047665722896385'],
#    'id': '1590047665722896385',
#    'text': "@klaydd_sylverr yessss let's claim it\U0001f979\U0001f979"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '8': {'data': {'edit_history_tweet_ids': ['1590047671079010305'],
#    'id': '1590047671079010305',
#    'text': "@joshgondelman @littlefieldnyc I'm going!"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '9': {'data': {'edit_history_tweet_ids': ['1590047673197162496'],
#    'id': '1590047673197162496',
#    'text': 'A BOMB Just Dropped on Biden The Day Before the MIDTERMS!!! https://t.co/qyT6lCzPdL via @YouTube'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '10': {'data': {'edit_history_tweet_ids': ['1590047669061550080'],
#    'id': '1590047669061550080',
#    'text': 'RT @NewKidInTown47: @CheriJacobus In terms of the midterms, Garland’s EPIC screw up was not indicting a single fake elector by now. It migh…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '11': {'data': {'edit_history_tweet_ids': ['1590047673805312000'],
#    'id': '1590047673805312000',
#    'text': 'RT @SinedWarrior: C’est parti pour le cirque ! Un agent électoral du très important comté de Maricopa en Arizona explique aux électeurs des…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '12': {'data': {'edit_history_tweet_ids': ['1590047678708449280'],
#    'id': '1590047678708449280',
#    'text': 'RT @nytimes: For most of the world, the U.S. midterms are little more than a blip — but they are another data point on what some see as a t…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '13': {'data': {'edit_history_tweet_ids': ['1590047680579112960'],
#    'id': '1590047680579112960',
#    'text': 'RT @CNNThisMorning: CNN EXCLUSIVE: @SpeakerPelosi says attack on her husband will impact decision over her political future post-midterms.…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '14': {'data': {'edit_history_tweet_ids': ['1590047681216270336'],
#    'id': '1590047681216270336',
#    'text': 'RT @ShayWoulahan: While I do get feminists frustration with women voting red in the midterms today, there’s no need to down play the damage…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '15': {'data': {'edit_history_tweet_ids': ['1590047681925128193'],
#    'id': '1590047681925128193',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '16': {'data': {'edit_history_tweet_ids': ['1590047679396315138'],
#    'id': '1590047679396315138',
#    'text': '@CNEWS Les milliards sont détournés et réinvestit en Suisse dans l immobilier par la mafia ukrainonazis, renseignez-vous, et vous constaterez par vous-même !!'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '17': {'data': {'edit_history_tweet_ids': ['1590047687730425858'],
#    'id': '1590047687730425858',
#    'text': 'RT @lordivan22: EUA 🇺🇸: “Midterms”\nA “decision desk” do PHVox projeta:\n\nCâmara: \nRepublicanos 233-238\nDemocratas 197-202\n\nSenado:\nRepublica…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '18': {'data': {'edit_history_tweet_ids': ['1590047686899945472'],
#    'id': '1590047686899945472',
#    'text': 'RT @newsbusters: The leftist media are all of a sudden talking about fears of cheating and hacking in the midterms now that Democrats are e…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '19': {'data': {'edit_history_tweet_ids': ['1590047692302200832'],
#    'id': '1590047692302200832',
#    'text': "RT @washingtonpost: Here's what time polls close and how long it might take to get election results for the 2022 midterms, according to the…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '20': {'data': {'edit_history_tweet_ids': ['1590047701672275969'],
#    'id': '1590047701672275969',
#    'text': "@Outkick So, it's official--Reiner has lost his mind and should be hospitalized"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '21': {'data': {'edit_history_tweet_ids': ['1590047705526841344'],
#    'id': '1590047705526841344',
#    'text': 'THIS is why when they cry "AUDIT!" we say THE WHOLE BALLOT OR NONE.\nThey never want the whole ballot audited.\nTHIS is how we get them and thier cheating and expose infighting. People wont want the WHOLE Ballot audited bc it might reveal they didnt win.\nWatch the fights begin! https://t.co/B5JQLJStKU'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '22': {'data': {'edit_history_tweet_ids': ['1590047705648070656'],
#    'id': '1590047705648070656',
#    'text': 'RT @anne_sinclair: Ce qu’est en train de devenir le parti républicain avec des héroïnes comme Marjorie Taylor Greene, candidate à la House…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '23': {'data': {'edit_history_tweet_ids': ['1590047705589747713'],
#    'id': '1590047705589747713',
#    'text': 'Die Midterms in den USA sind eine Teilentscheidung ob der freie Westen bestand haben wird. Umso weniger verständlich für mich wie viele deutsche Liberale und Konservative auf einen Sieg der in großen Teilen isolationistischen GOP hoffen.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '24': {'data': {'edit_history_tweet_ids': ['1590047704389779456'],
#    'id': '1590047704389779456',
#    'text': '@lordivan22 Em que isso influencia no Brasil?  Tem alguma conexão com o fato das FFAA deixar para amanhã a entrega do tão esperado relatório?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '25': {'data': {'edit_history_tweet_ids': ['1590047704037879808'],
#    'id': '1590047704037879808',
#    'text': "@MSNBC I don't get it... 90% of media figures have demanded their followers vote blue. And everyone cheers.\nBut ohh... Elon SUGGESTS voting Republican, and everyone flips their wig!"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '26': {'data': {'edit_history_tweet_ids': ['1590047702678900737'],
#    'id': '1590047702678900737',
#    'text': '@funguy6113 Definitely 😁'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '27': {'data': {'edit_history_tweet_ids': ['1590047705010561024'],
#    'id': '1590047705010561024',
#    'text': 'THE U.S. MIDTERMS &amp;amp; BRAZIL - A WEEK THAT CAN PROFOUNDLY AFFECT THE FUTURE | 08.11.2022 https://t.co/8HOb5Tzq3f'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '28': {'data': {'edit_history_tweet_ids': ['1590047704847355904'],
#    'id': '1590047704847355904',
#    'text': 'Changes Afoot Whatever Midterms\xa0Bring https://t.co/KZF9hJdjCQ'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '29': {'data': {'edit_history_tweet_ids': ['1590047705195507712'],
#    'id': '1590047705195507712',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '30': {'data': {'edit_history_tweet_ids': ['1590047706915172352'],
#    'id': '1590047706915172352',
#    'text': '@HalaForzaGGMU @POTUS You couldn’t possibly have been a republican and be this stupid'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '31': {'data': {'edit_history_tweet_ids': ['1590047707791773696'],
#    'id': '1590047707791773696',
#    'text': 'RT @Reekedson_TR: Counting will continue for another week at least! We are screwed just like in 2020. Dominion is at it again! #DominionDow…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '32': {'data': {'edit_history_tweet_ids': ['1590047708748066816'],
#    'id': '1590047708748066816',
#    'text': 'RT @JennaJordanTV: Democratic candidate for U.S. Senate @TimRyan pounding the pavement and knocking on doors with Cleveland @MayorBibb, enc…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '33': {'data': {'edit_history_tweet_ids': ['1590047709402402816'],
#    'id': '1590047709402402816',
#    'text': 'RT @emmanuelfelton: Secretary of State Cord Byrd of Florida is the latest Republican official to reject Justice Department requests to plac…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '34': {'data': {'edit_history_tweet_ids': ['1590047705463926784'],
#    'id': '1590047705463926784',
#    'text': '@Reuters https://t.co/P10Az79rvl'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '35': {'data': {'edit_history_tweet_ids': ['1590047707087130625'],
#    'id': '1590047707087130625',
#    'text': 'RT @DebatF24: 🇺🇸🗳️ #Midterms : un test pour la démocratie ?\n\nMais que sont exactement ces élections de mi-mandat ? Comment fonctionnent-ell…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '36': {'data': {'edit_history_tweet_ids': ['1590047709771493377'],
#    'id': '1590047709771493377',
#    'text': '@CNN Taiwan stocks have entered the pullback buying stage this week! Band set sail! Implement the detection of individual stocks, and choose the stocks or change the stocks to make money!\n★★★Please click the website to enter↓ ★★★\nhttps://t.co/MK3rugYOAK'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37': {'data': {'edit_history_tweet_ids': ['1590047713898680320'],
#    'id': '1590047713898680320',
#    'text': '@bookyblonde Aye, lethargy reigns.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38': {'data': {'edit_history_tweet_ids': ['1590047712447266816'],
#    'id': '1590047712447266816',
#    'text': "I've usually posted something by now, but with election day my attention needs to be on the Slate comments.\n\nI plan to do one post today, probably in the evening, and have some sort of takeaways from the midterms through the frame of how well anti-trans propaganda worked."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '39': {'data': {'edit_history_tweet_ids': ['1590047713487650816'],
#    'id': '1590047713487650816',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '40': {'data': {'edit_history_tweet_ids': ['1590047716222337024'],
#    'id': '1590047716222337024',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '41': {'data': {'edit_history_tweet_ids': ['1590047716889223169'],
#    'id': '1590047716889223169',
#    'text': 'RT @StevenBeschloss: One note before the midterms: Nov. 9 would be a fine day for Merrick Garland to indict Donald J. Trump for crimes rela…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '42': {'data': {'edit_history_tweet_ids': ['1590047716054536192'],
#    'id': '1590047716054536192',
#    'text': '@FoxNews FAULTY VOTING Machines are being "Whisked-Off" to the MAIN Counting Centers!\nHa, ha!!!!!!!!\nThose "FAULTY MACHINES" were Probably STUFFED WITH VOTES LAST NIGHT by whatever People DESPERATELY Want to ensure their ""ILLEGAL"" Victory.!!!!\n\nHa, ha!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! https://t.co/kHRJ3p2XoM'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '43': {'data': {'edit_history_tweet_ids': ['1590047716738240512'],
#    'id': '1590047716738240512',
#    'text': 'RT @CastizoCapitan: The midterms are upon us. Remember, a vote for Republicans is a vote for Fascism! https://t.co/oDB1Nyo4F0'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '44': {'data': {'edit_history_tweet_ids': ['1590047716587220992'],
#    'id': '1590047716587220992',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '45': {'data': {'edit_history_tweet_ids': ['1590047718713749505'],
#    'id': '1590047718713749505',
#    'text': '@Cdanslair @anne_sinclair @LeHuffPost @Caroline_Roux @France5tv La plus grosse cocue du monde, qui voyait DSK en saint sauveur, va nous éclairer sur lz monde du réel. Waow.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '46': {'data': {'edit_history_tweet_ids': ['1590047717631623169'],
#    'id': '1590047717631623169',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '47': {'data': {'edit_history_tweet_ids': ['1590047718302699520'],
#    'id': '1590047718302699520',
#    'text': '@CalltoActivism I’m voting republican because I don’t want anymore socialism. I determined that in my own. There something called free speech. Your welcome to vote how you feel is right. Elon’s not forcing you to vote his way. It’s his company.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '48': {'data': {'edit_history_tweet_ids': ['1590047719611305984'],
#    'id': '1590047719611305984',
#    'text': 'Bardzo odważne prognozy👇 https://t.co/Ey3x38dyZf'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '49': {'data': {'edit_history_tweet_ids': ['1590047718340145152'],
#    'id': '1590047718340145152',
#    'text': 'RT @AMErikaNGIRLLL: ALERT ARIZONA 🛑 #VoteRed2022 #VotingIrregularities #midterms https://t.co/kRrMTT6pTl'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '50': {'data': {'edit_history_tweet_ids': ['1590047719262801921'],
#    'id': '1590047719262801921',
#    'text': "RT @washingtonpost: Here's what time polls close and how long it might take to get election results for the 2022 midterms, according to the…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '51': {'data': {'edit_history_tweet_ids': ['1590047725759868928'],
#    'id': '1590047725759868928',
#    'text': 'RT @QuynhMontgomery: Filled with anxiety over midterms &amp; local elections. Taking a breather but had to share these crazy, beautiful fall co…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '52': {'data': {'edit_history_tweet_ids': ['1590047722949992448'],
#    'id': '1590047722949992448',
#    'text': '@VeraMBergen @wiczipedia In California taking photos or videos in a polling place is prohibited by law'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '53': {'data': {'edit_history_tweet_ids': ['1590047726884249602'],
#    'id': '1590047726884249602',
#    'text': 'RT @ardenthistorian: Wahltag, das Signal für diverses "was kümmerst du dich um die USA kümmer dich lieber um Deutschland" Gepöbele. Sweet p…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '54': {'data': {'edit_history_tweet_ids': ['1590047727068409856'],
#    'id': '1590047727068409856',
#    'text': 'RT @BOROWSKIMIKE: Elections "midterms" américaines d\'après les derniers sondages les républicains de Donald Trump gagneraient 84 sièges sur…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '55': {'data': {'edit_history_tweet_ids': ['1590047730486812672'],
#    'id': '1590047730486812672',
#    'text': 'RT @LetItShine69: 🤔"Employée des élections du comté de #Maricopa :\nRien ne marche depuis une demi-heure." (via Guerrieri per la libertà)\n#U…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '56': {'data': {'edit_history_tweet_ids': ['1590047728088010752'],
#    'id': '1590047728088010752',
#    'text': '@atrupar https://t.co/YqCbzAt4Qy'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '57': {'data': {'edit_history_tweet_ids': ['1590047725462376448'],
#    'id': '1590047725462376448',
#    'text': 'RT @GOGUYGO_: Gonna be having a great conversation about #MultiversX with some friends.\n- #EGLD \n- New X products\n- people that were at the…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '58': {'data': {'edit_history_tweet_ids': ['1590047730004807680'],
#    'id': '1590047730004807680',
#    'text': "@MSNBC Quite sure that if you both sat for a logical reasoning test , @ZeeshanAleem's score will be around 10% the score of @elonmusk......he's designing rockets, you're writing bollocks on @MSNBC 😂"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '59': {'data': {'edit_history_tweet_ids': ['1590047730994671616'],
#    'id': '1590047730994671616',
#    'text': 'Vote in the midterms today — it’s what Aaron Carter would have wanted 🕊️'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '60': {'data': {'edit_history_tweet_ids': ['1590047732064227329'],
#    'id': '1590047732064227329',
#    'text': 'RT @JonathanTurley: ...Courts have the authority to extend hours if voting is delayed by such malfunctions. Secretary of State Katie Hobbs…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '61': {'data': {'edit_history_tweet_ids': ['1590047731514740736'],
#    'id': '1590047731514740736',
#    'text': '@FoxNews I don’t watch SNL anymore since they don’t kill it anymore without Baldwin'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '62': {'data': {'edit_history_tweet_ids': ['1590047734182002688'],
#    'id': '1590047734182002688',
#    'text': 'RT @nypost: Dow jumps 500 points as Wall Street bets on red wave in midterms https://t.co/vzx3Mc6xZs https://t.co/gT2sbl46du'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '63': {'data': {'edit_history_tweet_ids': ['1590047734274306056'],
#    'id': '1590047734274306056',
#    'text': 'Wenn die GOP gewinnt, verlieren wir alle. Aber insbesondere Ukraine.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '64': {'data': {'edit_history_tweet_ids': ['1590047732726517760'],
#    'id': '1590047732726517760',
#    'text': '@LBC @AndrewMarr9 with this crap economy? 100%'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '65': {'data': {'edit_history_tweet_ids': ['1590047732244557825'],
#    'id': '1590047732244557825',
#    'text': "@MikeSte77 @Disneycast2008 @INDems @cdiegomorales @indgop where the hell are you hearing that? \nDems are expected to loose the house as is normal for the party in power to loose power during midterms \nthe fact that is highly contested tells you the failure of the republican party and how far right they've gone even life long reps are t"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '66': {'data': {'edit_history_tweet_ids': ['1590047736191422464'],
#    'id': '1590047736191422464',
#    'text': 'RT @OtherKindsMoney: Ready for a rollercoaster week in the market?\n\n- CPI data\n- US Midterms\n- Crypto Whale Wars\n\nPrepare for volatility ev…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '67': {'data': {'edit_history_tweet_ids': ['1590047736409518080'],
#    'id': '1590047736409518080',
#    'text': 'Midterm elections 2022: Americans head to polls with control of Congress at stake – live https://t.co/sIBJFiTy6k'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '68': {'data': {'edit_history_tweet_ids': ['1590047740096286720'],
#    'id': '1590047740096286720',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '69': {'data': {'edit_history_tweet_ids': ['1590047742893907968'],
#    'id': '1590047742893907968',
#    'text': 'No one goes faster from "you can\'t rig US elections" to "we lost, the elections mst be rigged" than Democrats... https://t.co/4B3N6QjtH9'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '70': {'data': {'edit_history_tweet_ids': ['1590047741778202625'],
#    'id': '1590047741778202625',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '71': {'data': {'edit_history_tweet_ids': ['1590047741610463232'],
#    'id': '1590047741610463232',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '72': {'data': {'edit_history_tweet_ids': ['1590047742629646336'],
#    'id': '1590047742629646336',
#    'text': 'At least one moderate group *already sent out* its analysis of why Democrats lost the midterms because of Wokeism https://t.co/PthKeGMGaF'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '73': {'data': {'edit_history_tweet_ids': ['1590047745485967361'],
#    'id': '1590047745485967361',
#    'text': 'RT @JonathanTurley: ...Courts have the authority to extend hours if voting is delayed by such malfunctions. Secretary of State Katie Hobbs…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '74': {'data': {'edit_history_tweet_ids': ['1590047744873619457'],
#    'id': '1590047744873619457',
#    'text': 'Not progressive enough? Mmkay. https://t.co/CgOjEDh1MT'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '75': {'data': {'edit_history_tweet_ids': ['1590047746421317638'],
#    'id': '1590047746421317638',
#    'text': 'RT @gop4senate2022: If Jimmy Carter was still alive, he would have voted republican in the 2022 midterms'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '76': {'data': {'edit_history_tweet_ids': ['1590047747201466368'],
#    'id': '1590047747201466368',
#    'text': 'RT @VABVOX: “Carefully, precisely, surgically and in our own way, as we know how. During our pinpoint operations, we will remove both kidne…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '77': {'data': {'edit_history_tweet_ids': ['1590047746970771456'],
#    'id': '1590047746970771456',
#    'text': 'RT @DwightKSchruteA: @voxdotcom You disgusting gaslighters.  This isn’t normal.\n\nEvery POTUS election since 1932 (save for 2000 &amp; 2020)  ha…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '78': {'data': {'edit_history_tweet_ids': ['1590047744701628416'],
#    'id': '1590047744701628416',
#    'text': '@jmhorp Not just the Trump wing, the kookiest part of the Trump wing.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '79': {'data': {'edit_history_tweet_ids': ['1590047750556876800'],
#    'id': '1590047750556876800',
#    'text': 'Democratic upset in U.S. midterms could roil markets, options mavens say https://t.co/wsEZruPcSh via @Yahoo'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '80': {'data': {'edit_history_tweet_ids': ['1590047751815188481'],
#    'id': '1590047751815188481',
#    'text': 'RT @EvanLeeDyer: I tried to warn. Dont let the Binance news today fool you. \nElections are not over yet https://t.co/zJpeMjuzFu\n#Midterms20…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '81': {'data': {'edit_history_tweet_ids': ['1590047748434571264'],
#    'id': '1590047748434571264',
#    'text': '@itsbday LFG'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '82': {'data': {'edit_history_tweet_ids': ['1590047750301057024'],
#    'id': '1590047750301057024',
#    'text': 'U.S. midterms: Americans to vote in ‘pivotal’ elections https://t.co/2B943CAByu'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '83': {'data': {'edit_history_tweet_ids': ['1590047751508619265'],
#    'id': '1590047751508619265',
#    'text': 'Get insights and comment from Duke experts on a  variety of election-related topics in NC and nationally. Email dukenews@duke.edu to arrange an interview. #ncpol #Midterms \nhttps://t.co/16RV265nG7 https://t.co/pp4wWR80z9'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '84': {'data': {'edit_history_tweet_ids': ['1590047751685173248'],
#    'id': '1590047751685173248',
#    'text': 'RT @mayawiley: Voting is a fundamental right. And neutral, non-partisan poll monitoring is a tradition. I did it in FL in 2004. I did it fo…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '85': {'data': {'edit_history_tweet_ids': ['1590047752293355520'],
#    'id': '1590047752293355520',
#    'text': '“Some of the people who are coming in have been manipulated into believing things are not on the up and up, and they may—deliberately or inadvertently—further undermine people’s confidence in the process through misunderstanding of the system.” @rickhasen  https://t.co/b3YPOXwAPp'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '86': {'data': {'edit_history_tweet_ids': ['1590047752771481601'],
#    'id': '1590047752771481601',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '87': {'data': {'edit_history_tweet_ids': ['1590047752557584384'],
#    'id': '1590047752557584384',
#    'text': 'RT @wjz: Women have held a majority in the electorate for decades. In the 2018 midterms, they made up 52% of voters. https://t.co/578nWGfq2h'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '88': {'data': {'edit_history_tweet_ids': ['1590047755468439552'],
#    'id': '1590047755468439552',
#    'text': '@FoxNews Do you think you can keep from announcing any winners until the polls are closed this time? That was beyond disgusting last time.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '89': {'data': {'edit_history_tweet_ids': ['1590047755510042624'],
#    'id': '1590047755510042624',
#    'text': 'Changes Afoot Whatever Midterms\xa0Bring https://t.co/bQPCe5RrE0'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '90': {'data': {'edit_history_tweet_ids': ['1590047755606851584'],
#    'id': '1590047755606851584',
#    'text': 'RT @RawStory: Russian state media reportedly rooting for big GOP win in midterms https://t.co/C1vnYB0cpc'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '91': {'data': {'edit_history_tweet_ids': ['1590047754579218432'],
#    'id': '1590047754579218432',
#    'text': "I'm on pins &amp; needles...Democratic upset in U.S. midterms could roil markets, options mavens say https://t.co/cnJUxNTyR0 via @Yahoo"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '92': {'data': {'edit_history_tweet_ids': ['1590047754939961345'],
#    'id': '1590047754939961345',
#    'text': '"Pedro, if you vote a straight R ticket it means Ukrainians might die" \n\nMe: RRRRRRRRRRRRRRRRRRR https://t.co/06AT4neaC5'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '93': {'data': {'edit_history_tweet_ids': ['1590047757439729664'],
#    'id': '1590047757439729664',
#    'text': '@FoxNews @GOPLeader https://t.co/4Flc0fIYVQ'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '94': {'data': {'edit_history_tweet_ids': ['1590047758790324224'],
#    'id': '1590047758790324224',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '95': {'data': {'edit_history_tweet_ids': ['1590047756500238336'],
#    'id': '1590047756500238336',
#    'text': 'RT @MichelleObama: It’s Election Day! Today is the last day to make your voice heard in the 2022 midterms — and the polls are open! \n\nHead…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '96': {'data': {'edit_history_tweet_ids': ['1590047759771795457'],
#    'id': '1590047759771795457',
#    'text': "RT @SteveRustad1: To hell with the polls.\n\nWe turn out like in 2020, we win the Midterms.\n\nLet's do this.\n\nVOTE BLUE!!!\n\n#VoteBlueToSaveDem…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '97': {'data': {'edit_history_tweet_ids': ['1590047758190510080'],
#    'id': '1590047758190510080',
#    'text': 'US Midterms. My thoughts, in one quote.\n\n"What you choose will never matter because everything is mine."\n\n- The System. \n(Otherwise known as Tom MacDonald)'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '98': {'data': {'edit_history_tweet_ids': ['1590047751207022593'],
#    'id': '1590047751207022593',
#    'text': 'I know these midterms are very nerve wracking across the pond, but at least I get to catch up by admiring Steve Kornacki crunch numbers like boss 🥊 https://t.co/oM4IvA3TKb'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '99': {'data': {'edit_history_tweet_ids': ['1590047763731214336'],
#    'id': '1590047763731214336',
#    'text': '@GOGUYGO_ @aubree_signals \n@MrM4J0R \n@0xdemetsh\n@zihadmahiuddin \n@JacobyJS'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '100': {'data': {'edit_history_tweet_ids': ['1590047764138065920'],
#    'id': '1590047764138065920',
#    'text': '#ElectionDay #AmericaFirst US Voting Live | Midterms Election 2022 | Former US President Donald Trump Casts His Vote In Florida\nhttps://t.co/Tlw9FfLyZH'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '101': {'data': {'edit_history_tweet_ids': ['1590047764662177792'],
#    'id': '1590047764662177792',
#    'text': 'Changes Afoot Whatever Midterms\xa0Bring https://t.co/N1jubicaDJ'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '102': {'data': {'edit_history_tweet_ids': ['1590047765396336640'],
#    'id': '1590047765396336640',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '103': {'data': {'edit_history_tweet_ids': ['1590047767778689024'],
#    'id': '1590047767778689024',
#    'text': '@BOROWSKIMIKE Attend la fraude arrive demain  ça sera le contraire'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '104': {'data': {'edit_history_tweet_ids': ['1590047761986392065'],
#    'id': '1590047761986392065',
#    'text': 'RT @NikGerassimow: Update #Ukraine \nIm Überblick:\n- russische Raketenangriffe gehen weiter, Stromabschaltungen in weiten Teilen der Ukraine…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '105': {'data': {'edit_history_tweet_ids': ['1590047765526360064'],
#    'id': '1590047765526360064',
#    'text': '@PhilipWegmann Washington is not a tossup.  That is ridiculous.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '106': {'data': {'edit_history_tweet_ids': ['1590047767732555776'],
#    'id': '1590047767732555776',
#    'text': "From what I'm hearing on the midterms in the USA, it seems the Republicans  are very happy, and the Democrats not so happy, wonder have they seen a preview of mailed in ballots and have an idea of which way the wind is blowing."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '107': {'data': {'edit_history_tweet_ids': ['1590047769297059840'],
#    'id': '1590047769297059840',
#    'text': '@RonFilipkowski This comes across as ironic when we know if this was instead folks of another religion enacting something symbolically referencing a well-known story from their holy book, many would likely call it hate speech. \n\nGets a pass because mocking Christians now part of leftist efforts.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '108': {'data': {'edit_history_tweet_ids': ['1590047770056224768'],
#    'id': '1590047770056224768',
#    'text': '@Reuters Thank you for helping to save our Country'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '109': {'data': {'edit_history_tweet_ids': ['1590047770161090560'],
#    'id': '1590047770161090560',
#    'text': "@ComicDaveSmith He is getting ready to deflect blame when BLM and ANTIFA start rioting again. They are the Democrat party's equivalent of Hitler's brown shirts."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '110': {'data': {'edit_history_tweet_ids': ['1590047770529845253'],
#    'id': '1590047770529845253',
#    'text': 'Midterm elections 2022: Americans head to polls with control of Congress at stake – live https://t.co/sIBJFjaB8k'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '111': {'data': {'edit_history_tweet_ids': ['1590047774812143616'],
#    'id': '1590047774812143616',
#    'text': 'With so many races so tightly contested, it wouldn’t take much for the final outcome of the midterms to feel very good, or very bad, for either party. https://t.co/GPwiIWA9WI'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '112': {'data': {'edit_history_tweet_ids': ['1590047776536395776'],
#    'id': '1590047776536395776',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '113': {'data': {'edit_history_tweet_ids': ['1590047777853083648'],
#    'id': '1590047777853083648',
#    'text': '#VoteBlueToSaveDemocracy #VoteBlueToProtectWomen #Vote #VoteBlueToday https://t.co/QNcCKuIIFB'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '114': {'data': {'edit_history_tweet_ids': ['1590047781640581120'],
#    'id': '1590047781640581120',
#    'text': 'RT @kingojungle: Just a reminder in case you don’t think your midterm vote matters. If conservatives win the midterms Biden will be impeach…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '115': {'data': {'edit_history_tweet_ids': ['1590047778885206019'],
#    'id': '1590047778885206019',
#    'text': '#VoteBlueToSaveDemocracy https://t.co/laFe2LKW2Y'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '116': {'data': {'edit_history_tweet_ids': ['1590047781305344000'],
#    'id': '1590047781305344000',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '117': {'data': {'edit_history_tweet_ids': ['1590047778289647616'],
#    'id': '1590047778289647616',
#    'text': '@JoJoFromJerz You must be rich and cluest as to what people are dealing with.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '118': {'data': {'edit_history_tweet_ids': ['1590047778662543360'],
#    'id': '1590047778662543360',
#    'text': 'https://t.co/0kEnEUDKqb'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '119': {'data': {'edit_history_tweet_ids': ['1590047781309550593'],
#    'id': '1590047781309550593',
#    'text': 'RT @lawyer4laws: Now the Press Tells Dems Why They’re in Trouble\n\nThe party’s media allies are a little late ...\n\n“Democrats Have Alienated…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '120': {'data': {'edit_history_tweet_ids': ['1590047785419931649'],
#    'id': '1590047785419931649',
#    'text': 'RT @tomiahonen: Let me also do the various election trends that hit this midterm and consider if they have been captured well in polling\n\nS…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '121': {'data': {'edit_history_tweet_ids': ['1590047782756585473'],
#    'id': '1590047782756585473',
#    'text': "RT @kylegriffin1: The Justice Department's Civil Rights Division says it will monitor polls in 64 jurisdictions in 24 states — including Al…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '122': {'data': {'edit_history_tweet_ids': ['1590047789475823616'],
#    'id': '1590047789475823616',
#    'text': 'RT @capeandcowell: Americans nervously watching midterms as economy hangs in the balance \n\nFixed it'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '123': {'data': {'edit_history_tweet_ids': ['1590047788150460416'],
#    'id': '1590047788150460416',
#    'text': 'RT @BurrdDoh: Oh I voted alright. \nI moved on that ballot like a bitch. \nYou know, I’m automatically attracted to polling stations. \nI just…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '124': {'data': {'edit_history_tweet_ids': ['1590047788129484801'],
#    'id': '1590047788129484801',
#    'text': 'RT @swiftness4271: 🗳️☑️🇺🇲 #redwave #RedWave2022 #RedTsunami2022 #RedTsunami #Vote #VoteRed2022 #ElectionDay #Election2022 #Midterms'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '125': {'data': {'edit_history_tweet_ids': ['1590047793129082880'],
#    'id': '1590047793129082880',
#    'text': '@tomiahonen @elonmusk please fact check this'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '126': {'data': {'edit_history_tweet_ids': ['1590047790079823872'],
#    'id': '1590047790079823872',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '127': {'data': {'edit_history_tweet_ids': ['1590047792499916800'],
#    'id': '1590047792499916800',
#    'text': "@MSNBC Hobbs inability to conduct an election in AZ today, since 20% of ballot machines in AZ'S most populated area are NOT WORKING, is REASON ALONE NOT TO VOTE for KATIE HOBBS TODAY."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '128': {'data': {'edit_history_tweet_ids': ['1590047793145843713'],
#    'id': '1590047793145843713',
#    'text': 'RT @BrittanyinTexas: With midterms underway, instead of focusing on what can go wrong I am excited about what can go right! #BetoForTexas'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '129': {'data': {'edit_history_tweet_ids': ['1590047794592886784'],
#    'id': '1590047794592886784',
#    'text': 'RT @lordivan22: EUA 🇺🇸: “Midterms”\nA “decision desk” do PHVox projeta:\n\nCâmara: \nRepublicanos 233-238\nDemocratas 197-202\n\nSenado:\nRepublica…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '130': {'data': {'edit_history_tweet_ids': ['1590047798099345415'],
#    'id': '1590047798099345415',
#    'text': '@ardenthistorian egal wies ausgeht beschissen wirds trotzdem'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '131': {'data': {'edit_history_tweet_ids': ['1590047795679203328'],
#    'id': '1590047795679203328',
#    'text': "@libe La classe moyenne américaine, et elle n'est pas la seule, ne comprend pas les causes de sa disparition et accélère même celle-ci.\nAvoir fait du Tiers Monde l'usine de la planète a créé d'autres classes moyennes qui les ont supplantées car le travail se trouvent dans leurs pays."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '132': {'data': {'edit_history_tweet_ids': ['1590047797596020736'],
#    'id': '1590047797596020736',
#    'text': '@kylenabecker I’m in Florida so yea.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '133': {'data': {'edit_history_tweet_ids': ['1590047805053116416'],
#    'id': '1590047805053116416',
#    'text': '@MsAngelineTW But damn happy that you live here, right?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '134': {'data': {'edit_history_tweet_ids': ['1590047803153485824'],
#    'id': '1590047803153485824',
#    'text': '🙄\n\n#VoteRed2022\n#RedTsunami2022\n#Midterms2022\n\nhttps://t.co/jcLIgqs1qd'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '135': {'data': {'edit_history_tweet_ids': ['1590047805368074241'],
#    'id': '1590047805368074241',
#    'text': 'RT @RSPolitics: Elon Musk in April: "For Twitter to deserve public trust, it must be politically neutral."\n\nElon Musk on Monday: "I recomme…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '136': {'data': {'edit_history_tweet_ids': ['1590047803438694401'],
#    'id': '1590047803438694401',
#    'text': 'RT @SinedWarrior: C’est parti pour le cirque ! Un agent électoral du très important comté de Maricopa en Arizona explique aux électeurs des…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '137': {'data': {'edit_history_tweet_ids': ['1590047803627417601'],
#    'id': '1590047803627417601',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '138': {'data': {'edit_history_tweet_ids': ['1590047804063645696'],
#    'id': '1590047804063645696',
#    'text': '#Votingrights https://t.co/xYLgPpHQp7'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '139': {'data': {'edit_history_tweet_ids': ['1590047803375771648'],
#    'id': '1590047803375771648',
#    'text': 'RT @AMErikaNGIRLLL: ALERT ARIZONA 🛑 #VoteRed2022 #VotingIrregularities #midterms https://t.co/kRrMTT6pTl'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '140': {'data': {'edit_history_tweet_ids': ['1590047808484413440'],
#    'id': '1590047808484413440',
#    'text': 'RT @lawyer4laws: Now the Press Tells Dems Why They’re in Trouble\n\nThe party’s media allies are a little late ...\n\n“Democrats Have Alienated…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '141': {'data': {'edit_history_tweet_ids': ['1590047808182136832'],
#    'id': '1590047808182136832',
#    'text': 'RT @PeterBorbe: Hoffentlich sind die amerikanischen Wähler heute weise genug, den kriegsbesoffenen Democrats, die die USA seit 2 Jahren mit…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '142': {'data': {'edit_history_tweet_ids': ['1590047810430586880'],
#    'id': '1590047810430586880',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '143': {'data': {'edit_history_tweet_ids': ['1590047809390391298'],
#    'id': '1590047809390391298',
#    'text': '@FoxNews Projection'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '144': {'data': {'edit_history_tweet_ids': ['1590047807184175104'],
#    'id': '1590047807184175104',
#    'text': '@RSPolitics “Recommend”'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '145': {'data': {'edit_history_tweet_ids': ['1590047810879361024'],
#    'id': '1590047810879361024',
#    'text': '@Reuters He is right, right! And the right is right! We choose the red pillow'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '146': {'data': {'edit_history_tweet_ids': ['1590047809101008897'],
#    'id': '1590047809101008897',
#    'text': 'RT @BOROWSKIMIKE: Elections "midterms" américaines d\'après les derniers sondages les républicains de Donald Trump gagneraient 84 sièges sur…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '147': {'data': {'edit_history_tweet_ids': ['1590047814301515776'],
#    'id': '1590047814301515776',
#    'text': '@franceinfo Ça ressemble plus à une démocratie que chez nous aux #EtatsUnis  !! Tous ces sujets sont décidés à notre place ici ...\n#Midterms2022 https://t.co/jAGf471SnT'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '148': {'data': {'edit_history_tweet_ids': ['1590047814381600769'],
#    'id': '1590047814381600769',
#    'text': '@MSNBC #Billionaires are all endorsing @GOP because they know @GOP has their back. This is EXACTLY why none of us should vote @GOP #Billionaires are trying to swing the election toward ending democracy. How does that feel when you know they are also building doomsday bunkers? @StateDept'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '149': {'data': {'edit_history_tweet_ids': ['1590047818840182784'],
#    'id': '1590047818840182784',
# ...
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '953': {'data': {'edit_history_tweet_ids': ['1590048703087534081'],
#    'id': '1590048703087534081',
#    'text': 'RT @Hasschami: DO NOT VOTE DEMOCRAT\n\n#ElectionDay #ElectionDay2022 #Midterms #GoVote https://t.co/VWnz9f2VZR'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '954': {'data': {'edit_history_tweet_ids': ['1590048704723316736'],
#    'id': '1590048704723316736',
#    'text': "RT @daveweigel: Total spending on 2018 midterms: $5.7 billion.\nTotal spending estimate on 2022 midterms: At least $16.7 billion.\n\nYou're no…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '955': {'data': {'edit_history_tweet_ids': ['1590048708548530176'],
#    'id': '1590048708548530176',
#    'text': "RT @RyanAFournier: It's no coincidence that on the night of midterms, the moon will be blood red."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '956': {'data': {'edit_history_tweet_ids': ['1590048708590456832'],
#    'id': '1590048708590456832',
#    'text': '@JoJoFromJerz Fool'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '957': {'data': {'edit_history_tweet_ids': ['1590048708460425216'],
#    'id': '1590048708460425216',
#    'text': '@esaagar @krystalball @ryangrim @emilyjashinsky @makosloff @KyleKulinski I will be tuning in. Love the show!'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '958': {'data': {'edit_history_tweet_ids': ['1590048708775022593'],
#    'id': '1590048708775022593',
#    'text': 'Les démocrates si mal placés pour parler de démocratie, ils abusent de leurs pouvoirs \nComme en France, les contre pouvoirs un à un ont été anéantis dévoyant ainsi l’idée même de pluralisme démocratique \nMême si les conservateurs ont des gamelles l’alternance est impérative https://t.co/SDHZMRFoQw'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '959': {'data': {'edit_history_tweet_ids': ['1590048709085401090'],
#    'id': '1590048709085401090',
#    'text': 'RT @kylegriffin1: Rep. James Clyburn to Fox: "Democracy will be ending" if Democrats lose the midterms.\n\n"I\'ve studied history all of my li…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '960': {'data': {'edit_history_tweet_ids': ['1590048709890699264'],
#    'id': '1590048709890699264',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '961': {'data': {'edit_history_tweet_ids': ['1590048715750141952'],
#    'id': '1590048715750141952',
#    'text': 'RT @JuliaDavisNews: Kremlin cheerleaders hope Republicans win big in the midterms.\n\n"Trump generates a lot of hatred in America’s society..…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '962': {'data': {'edit_history_tweet_ids': ['1590048716245045248'],
#    'id': '1590048716245045248',
#    'text': '@JoJoFromJerz Of course you are...because you are a Muthafucking Clown! Just like President Shit-His-Pants.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '963': {'data': {'edit_history_tweet_ids': ['1590048717893439488'],
#    'id': '1590048717893439488',
#    'text': '#ElectionDay Hoy vota un país polarizado. Aquí un recorrido por las dos campañas, en dos de los estados más reñidos. Viaje a las dos américas de estas Midterms, con @IouFerrerons https://t.co/2jRnRuMqaH'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '964': {'data': {'edit_history_tweet_ids': ['1590048717553676289'],
#    'id': '1590048717553676289',
#    'text': '@TheLeoTerrell She seems to act now like the attack on her husband will further her decision in retiring? I call it BS, If they lose the midterms! Shes over, The true colors of conniving lies deceit will come out of nancy pelosi, She will most likely call it quits after these results,'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '965': {'data': {'edit_history_tweet_ids': ['1590048728169467904'],
#    'id': '1590048728169467904',
#    'text': "What's the Vegas line that @bdomenech is right on this one?  I'll lay 17:1 in favor and we'll see evidence before December 15th.\nhttps://t.co/3XRRtLpXRN"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '966': {'data': {'edit_history_tweet_ids': ['1590048726231691265'],
#    'id': '1590048726231691265',
#    'text': '@KATUNews Yes! Ranked choice voting is a fantastic solution to remedy the two-party system we find ourselves in. It just makes sense. Everyone should be in favor of this, it puts more power in the hands of all voters. (Even conservatives!)'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '967': {'data': {'edit_history_tweet_ids': ['1590048724117786624'],
#    'id': '1590048724117786624',
#    'text': "Turnout in (deep-blue) Fairfax County - where's Reps. Gerry Connolly (D) and Don Beyer (D) will win easily - is at ~38% as of 1 pm. Last year - when there were statewide races and also House of Delegates elections - as of 1 pm, Fairfax turnout was at ~40%. https://t.co/hoMSemXxtA https://t.co/fhKIHmABU9"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '968': {'data': {'edit_history_tweet_ids': ['1590048726068125697'],
#    'id': '1590048726068125697',
#    'text': 'RT @DailyMail: Midterms voting starts with reported problems in Arizona, PA and New Jersey https://t.co/Ikwy4BPvBv'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '969': {'data': {'edit_history_tweet_ids': ['1590048733584297984'],
#    'id': '1590048733584297984',
#    'text': '@maitlis Was just wondering when we might know the outcomes. #midterms \nLooking long and messy. Might park up until Friday. 😬'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '970': {'data': {'edit_history_tweet_ids': ['1590048733445513216'],
#    'id': '1590048733445513216',
#    'text': 'Voter turnout checks in at just below 42% with a little more than five and a half hours left to vote. Most of those votes came through mail (30,000) and early voting (28,000), with a little less than 18,000 votes cast today.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '971': {'data': {'edit_history_tweet_ids': ['1590048730442477568'],
#    'id': '1590048730442477568',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '972': {'data': {'edit_history_tweet_ids': ['1590048733886124032'],
#    'id': '1590048733886124032',
#    'text': 'Abortion rights driving young women to vote in\xa0midterms https://t.co/baVZb6x3WE'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '973': {'data': {'edit_history_tweet_ids': ['1590048737833136129'],
#    'id': '1590048737833136129',
#    'text': 'RT @VSioufas: Midterms:\nΟι Αμερικανοί πρόκειται να επιφέρουν καίριο πλήγμα στην διακυβέρνηση Biden με ρεπουμπλικανικές νίκες στην Βουλή και…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '974': {'data': {'edit_history_tweet_ids': ['1590048735509512193'],
#    'id': '1590048735509512193',
#    'text': 'RT @kylenabecker: Still feel like the election integrity laws passed in your state are strong enough for the 2022 midterms?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '975': {'data': {'edit_history_tweet_ids': ['1590048737011060736'],
#    'id': '1590048737011060736',
#    'text': "Not really. The world is a smaller place now\n\n🔴They know that geriatric Biden and the Dems ran away in Afghanistan and humiliated the US around the world.\n\n🔴They know that Biden didn't finish that wall and millions have flooded in (an invasion like ours)\n\n🔴They just know! https://t.co/N4o9fNZa5J"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '976': {'data': {'edit_history_tweet_ids': ['1590048737040433156'],
#    'id': '1590048737040433156',
#    'text': 'RT @TimInHonolulu: 1. I reported that I thought #45 would be charged soon after midterms.  Patel’s grand jury testimony tells me that they…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '977': {'data': {'edit_history_tweet_ids': ['1590048739254620160'],
#    'id': '1590048739254620160',
#    'text': 'Fact-checkers suddenly rip into President Biden heading into midterms\n\nhttps://t.co/6Jk4NUri0Q'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '978': {'data': {'edit_history_tweet_ids': ['1590048738206429184'],
#    'id': '1590048738206429184',
#    'text': '@FoxNews https://t.co/AM8WW2ZZU2'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '979': {'data': {'edit_history_tweet_ids': ['1590048738957197313'],
#    'id': '1590048738957197313',
#    'text': 'Will Biden be forced to resign after the democrats take a massive defeat in the midterms?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '980': {'data': {'edit_history_tweet_ids': ['1590048740458758144'],
#    'id': '1590048740458758144',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '981': {'data': {'edit_history_tweet_ids': ['1590048746087358464'],
#    'id': '1590048746087358464',
#    'text': 'US midterms: Legalising marijuana on the ballot in five states | US Midterm Elections 2022\xa0News https://t.co/xmL2Q9A6cS'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '982': {'data': {'edit_history_tweet_ids': ['1590048746133688321'],
#    'id': '1590048746133688321',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '983': {'data': {'edit_history_tweet_ids': ['1590048742740484101'],
#    'id': '1590048742740484101',
#    'text': 'RT @OANN: #InFocus --- Nancy Pelosi Could Retire If Dems Lose Midterms: Report https://t.co/3mShqr56As #OAN'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '984': {'data': {'edit_history_tweet_ids': ['1590048743625478144'],
#    'id': '1590048743625478144',
#    'text': 'Vandaag zijn in de Verenigde Staten de midterms, de tussentijdse verkiezingen voor het Huis van Afgevaardigden en de Senaat. Er staat veel op het spel. Amerika-kenner Laila Frank @Frankiegoeswest: “Amerikanen maken zich oprecht heel veel zorgen.“ #KhalidenSophie https://t.co/GxSoytre8h'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '985': {'data': {'edit_history_tweet_ids': ['1590048744674066434'],
#    'id': '1590048744674066434',
#    'text': '@Reekedson_TR Not again! We can’t allow this. https://t.co/M2qlPfW7JN'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '986': {'data': {'edit_history_tweet_ids': ['1590048742413336576'],
#    'id': '1590048742413336576',
#    'text': "RT @muke10101: socdems still determined to be as annoying as ever but note how the ppl on the left here don't actually exist right now - ge…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '987': {'data': {'edit_history_tweet_ids': ['1590048747844947969'],
#    'id': '1590048747844947969',
#    'text': "@Daily_Express @Nigel_Farage What is Nigel Farage's favourite colour?"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '988': {'data': {'edit_history_tweet_ids': ['1590048748289523712'],
#    'id': '1590048748289523712',
#    'text': 'RT @JonathanTurley: ...Courts have the authority to extend hours if voting is delayed by such malfunctions. Secretary of State Katie Hobbs…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '989': {'data': {'edit_history_tweet_ids': ['1590048740290998272'],
#    'id': '1590048740290998272',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '990': {'data': {'edit_history_tweet_ids': ['1590048750135054336'],
#    'id': '1590048750135054336',
#    'text': "@ComicDaveSmith @Cernovich Why wouldn't he? He stated he had the biggest voting steal operation going on in 2020. lol Why do you people expect different results when nothing has been fixed. Go stand in line for hours only for your vote to be stolen. Congratulations!"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '991': {'data': {'edit_history_tweet_ids': ['1590048751552729088'],
#    'id': '1590048751552729088',
#    'text': '@DebatF24 @FRANCE24 @nabia_makhloufi 11/8/22:: WATCH #FRANKSPEECH #LINDELLTV LIVE COVERAGE ALL DAY OF ISSUES WITH VOTING ALL OVER THE COUNTRY. AND WHAT YOU SHOULD DO. \nhttps://t.co/fiL3kNVIYO'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '992': {'data': {'edit_history_tweet_ids': ['1590048753796673536'],
#    'id': '1590048753796673536',
#    'text': 'RT @nypost: Dow jumps 500 points as Wall Street bets on red wave in midterms https://t.co/vzx3Mc6xZs https://t.co/gT2sbl46du'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '993': {'data': {'edit_history_tweet_ids': ['1590048757357608960'],
#    'id': '1590048757357608960',
#    'text': 'RT @1NikolaMirkovic: George Soros a "donné" plus de  128 millions de $ au Parti Democrat US pour les élections de mi-mandat. #ElectionDay #…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '994': {'data': {'edit_history_tweet_ids': ['1590048757852557312'],
#    'id': '1590048757852557312',
#    'text': 'RT @AmakaUbakaTV: .@SecretaryOfMass says early voting numbers in MA are down compared to the 2018 midterms.\n\nMore than 1.1M ballots were ma…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '995': {'data': {'edit_history_tweet_ids': ['1590048758385217537'],
#    'id': '1590048758385217537',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '996': {'data': {'edit_history_tweet_ids': ['1590048760532697088'],
#    'id': '1590048760532697088',
#    'text': 'RT @nytimes: For most of the world, the U.S. midterms are little more than a blip — but they are another data point on what some see as a t…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '997': {'data': {'edit_history_tweet_ids': ['1590048762587934724'],
#    'id': '1590048762587934724',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '998': {'data': {'edit_history_tweet_ids': ['1590048762470465536'],
#    'id': '1590048762470465536',
#    'text': '@Schnabelobst Ich bleib auf 🥳'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '999': {'data': {'edit_history_tweet_ids': ['1590048760662732800'],
#    'id': '1590048760662732800',
#    'text': "To: All Americans\nWhat Did I Say About The Democrats? They Aren't Honest People/Who Appears 2B Rigging 2022 Midterms...Its Time 2Rid Democrats/Replaced Them With (New) Indepebdent Party..."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  ...}

# %%
len(tweets)
# Out:
# 75567

# %%
tweets1 = {}
tweets2 = {}
for num in range(len(tweets)-1):
    if num < len(tweets)//2:
        tweets1[str(num)] = tweets[str(num)]
    else:
        tweets2[str(num)] = tweets[str(num)]

# %%
len(tweets2)
# Out:
# 37783

# %%
coll.insert_many([tweets1])

# %%
tweets1['0']
# Out:
# {'data': {'edit_history_tweet_ids': ['1590047656314691584'],
#   'id': '1590047656314691584',
#   'text': 'RT @CologeroGetz: Arizona! Here are some important names to remember and pictures to share on your social media today!\n\nAbe Hamadeh for Att…'},
#  'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]}

# %%
coll = db["MidtermTweets2"]

# %%
res = coll.insert_many([tweets2])

# %%
res

# %%
res = coll.find()
print(res[0])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
res

# %%
res[0]
# Out:
# {'_id': ObjectId('6384b288a027f26e0334ff1c'),
#  '37783': {'data': {'edit_history_tweet_ids': ['1590088655481188352'],
#    'id': '1590088655481188352',
#    'text': "RT @AmandaMarcotte: The Elon Musk Twitter takeover is, in theory, a sideshow to the real story: American democracy in peril. But it's so pr…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37784': {'data': {'edit_history_tweet_ids': ['1590088655628283906'],
#    'id': '1590088655628283906',
#    'text': '“With regards to these latest accusations of election interference, #Moscow is understandably losing its patience. It requires either a certain lack of self-awareness, or an astonishing excess of arrogance, for the #UnitedStates to lecture any country on the question of meddling”'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37785': {'data': {'edit_history_tweet_ids': ['1590088657381523461'],
#    'id': '1590088657381523461',
#    'text': 'RT @AmoneyResists: 🚨 BREAKING: Chief “Justice” John Roberts just blocked the release of Trump’s tax returns to the House Ways and Means Com…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37786': {'data': {'edit_history_tweet_ids': ['1590088662770864129'],
#    'id': '1590088662770864129',
#    'text': 'How this college stu̡dent generated $224,923 in 3 months by dropshipping with Spocket ️\n\n👉https://t.co/8cFHZDost9\n\n#apobangpo #voteblue2022 #aptosnfts #series #n806mr #cbp #killabears #midterms https://t.co/yMG7Sx6ygU'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37787': {'data': {'edit_history_tweet_ids': ['1590088662045577217'],
#    'id': '1590088662045577217',
#    'text': 'RT @2_bloempje: Draadje: 8-11 Maar van #electionfraude is uiteraard geen sprake. Die meneer is kiezers die een verkeerde keuze maakten alle…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37788': {'data': {'edit_history_tweet_ids': ['1590088660568838144'],
#    'id': '1590088660568838144',
#    'text': '@atRachelGilmore They could always do a drag show if they want to be friends'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37789': {'data': {'edit_history_tweet_ids': ['1590088660548214784'],
#    'id': '1590088660548214784',
#    'text': 'RT @elmundoes: Trump hace de las \'midterms\' su trampolín de vuelta a la primera línea de política: "Voy a hacer un anuncio muy importante e…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37790': {'data': {'edit_history_tweet_ids': ['1590088663178047489'],
#    'id': '1590088663178047489',
#    'text': 'RT @politicsrea: PRESIDENT BIDEN’S FINAL AVERAGE APPROVAL RATING BEFORE THE MIDTERMS\n\nApprove: 43% (-11.29%)\nDisapprove: 55% https://t.co/a…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37791': {'data': {'edit_history_tweet_ids': ['1590088665040318464'],
#    'id': '1590088665040318464',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37792': {'data': {'edit_history_tweet_ids': ['1590088664608301056'],
#    'id': '1590088664608301056',
#    'text': 'A 22.10 sur @franceinfo radio avec @julien_langlet  pour un dernier point #midterms avant le dodo😉. Venez nombreuses et nombreux!!'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37793': {'data': {'edit_history_tweet_ids': ['1590088671143034880'],
#    'id': '1590088671143034880',
#    'text': 'RT @EugeneDaniels2: Trump on DeSantis: “If he did run, I will tell you things about him that won’t be very flattering. I know more about hi…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37794': {'data': {'edit_history_tweet_ids': ['1590088668018274304'],
#    'id': '1590088668018274304',
#    'text': 'RT @EdRaposo_: As midterms americanas desse ano provam a mutreta presidencial de 2020 da mesma maneira que o primeiro turno daqui, eleições…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37795': {'data': {'edit_history_tweet_ids': ['1590088671122067456'],
#    'id': '1590088671122067456',
#    'text': 'RT @leftcoastbabe: Stephen Colbert on Midterms Eve.  \n\n"Leave out a plate of cookies and cold glass of Xanax.  A lot of people are anxious…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37796': {'data': {'edit_history_tweet_ids': ['1590088668848717824'],
#    'id': '1590088668848717824',
#    'text': 'RT @EugeneDaniels2: Trump on DeSantis: “If he did run, I will tell you things about him that won’t be very flattering. I know more about hi…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37797': {'data': {'edit_history_tweet_ids': ['1590088673739304961'],
#    'id': '1590088673739304961',
#    'text': 'Somehoww, He s useful Here🤪 https://t.co/prYk5jwR8O'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37798': {'data': {'edit_history_tweet_ids': ['1590088675119206400'],
#    'id': '1590088675119206400',
#    'text': 'RT @bookculture: it is a truth universally acknowledged that if you remember to vote in the midterms you can buy up to five books this week…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37799': {'data': {'edit_history_tweet_ids': ['1590088674540388352'],
#    'id': '1590088674540388352',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37800': {'data': {'edit_history_tweet_ids': ['1590088676591030272'],
#    'id': '1590088676591030272',
#    'text': 'RT @MattWalshBlog: Also, nice job launching your public attack against the most popular conservative governor in America three days before…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37801': {'data': {'edit_history_tweet_ids': ['1590088677786427393'],
#    'id': '1590088677786427393',
#    'text': '@kingojungle Looking forward to it. Trump was an ass but this guy is flat-out incompetent.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37802': {'data': {'edit_history_tweet_ids': ['1590088679195693056'],
#    'id': '1590088679195693056',
#    'text': 'RT @ClassicalSocdem: For the 🇺🇸 midterms, I endorse all the Italians🇮🇹 running:\n\nSenate\nIL: Salvi (R)\nNV: Cortez Masto (D)\nOH: Ryan (D)\nVT:…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37803': {'data': {'edit_history_tweet_ids': ['1590088677891473410'],
#    'id': '1590088677891473410',
#    'text': 'RT @KevinEAbner: @TheDemocrats Remember that the only thing the Democrats are doing is increasing the cost of everything with the goal to b…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37804': {'data': {'edit_history_tweet_ids': ['1590088683121954816'],
#    'id': '1590088683121954816',
#    'text': 'men ba3d el midterms hazaker awel b awel w msh harham awa2el el dof3a'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37805': {'data': {'edit_history_tweet_ids': ['1590088684472188928'],
#    'id': '1590088684472188928',
#    'text': '@JeffOnTheRight Take a video. Love to see this bullshit.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37806': {'data': {'edit_history_tweet_ids': ['1590088680131416066'],
#    'id': '1590088680131416066',
#    'text': 'Election day coverage with @ethevessen and Marietta Slomka for @ZDF ! 🇺🇸🗳#Midterms https://t.co/2TLzoG2flS'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37807': {'data': {'edit_history_tweet_ids': ['1590088681532305409'],
#    'id': '1590088681532305409',
#    'text': '@AriMelber Xanax'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37808': {'data': {'edit_history_tweet_ids': ['1590088681817538561'],
#    'id': '1590088681817538561',
#    'text': 'Midterms been busing my behind'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37809': {'data': {'edit_history_tweet_ids': ['1590088680978649088'],
#    'id': '1590088680978649088',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37810': {'data': {'edit_history_tweet_ids': ['1590088686104104960'],
#    'id': '1590088686104104960',
#    'text': 'The 2022 Midterms Are a Referendum on the Future of Democracy in the US https://t.co/qf7jnw6iKK via @truthout'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37811': {'data': {'edit_history_tweet_ids': ['1590088685537882112'],
#    'id': '1590088685537882112',
#    'text': "RT @F2Washington: 🗳 En ce jour de #midterms, difficile de prédire les futurs résultats aux États-Unis 🇺🇸\n\nEn cause : les millions d'électeu…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37812': {'data': {'edit_history_tweet_ids': ['1590088688666816512'],
#    'id': '1590088688666816512',
#    'text': '@bcatini Rom DeSantis ocupará o lugar do Trump'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37813': {'data': {'edit_history_tweet_ids': ['1590088685953114113'],
#    'id': '1590088685953114113',
#    'text': 'RT @mitchellreports: Tom Bonier: Increased gender gap in early vote is an ‘early sign’ of abortion’s role in 2022 midterms @tbonier @Cecile…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37814': {'data': {'edit_history_tweet_ids': ['1590088686238302208'],
#    'id': '1590088686238302208',
#    'text': '#Biden connected👇#Midterm2022 #Midterms2022 #Midterms #Vote #GOP #freedom #VoteBlueIn2022 #VoteBlueForDemocracy #VoteRed2022 #VoteBlue #VoteBlueToSaveAmerica #VoteBlueToday #Bidenflation #trump #ElectionDay #ElectionDay2022 #MAGA #USA #elections #election #voting #votetoday https://t.co/lE4jXiMl8e'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37815': {'data': {'edit_history_tweet_ids': ['1590088686934577152'],
#    'id': '1590088686934577152',
#    'text': '@dw_espanol La libre Expresión lo favorece !!'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37816': {'data': {'edit_history_tweet_ids': ['1590088692261359616'],
#    'id': '1590088692261359616',
#    'text': 'RT @Vpauline006: États-Unis 🇺🇸 La triche en direct  à Philadelphie, en Pennsylvanie. #Midterms Q 🐸😳\U0001fae3🥴 https://t.co/S8Vs98zQOG'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37817': {'data': {'edit_history_tweet_ids': ['1590088690436812800'],
#    'id': '1590088690436812800',
#    'text': 'RT @PaulBongiorno: The prospect of the loud, vulgar, corrupt, narcissist  and liar Donald Trump and his bizarre, conspiracy theory candidat…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37818': {'data': {'edit_history_tweet_ids': ['1590088693024722945'],
#    'id': '1590088693024722945',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37819': {'data': {'edit_history_tweet_ids': ['1590088691858681856'],
#    'id': '1590088691858681856',
#    'text': 'RT @kingojungle: Just a reminder in case you don’t think your midterm vote matters. If conservatives win the midterms Biden will be impeach…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37820': {'data': {'edit_history_tweet_ids': ['1590088695356719104'],
#    'id': '1590088695356719104',
#    'text': "@RMCInfo Pour les gauchistes les 75 millions d'Américains qui ont voté Trump sont racistes et complotistes https://t.co/q2ylTxscGa"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37821': {'data': {'edit_history_tweet_ids': ['1590088695272513537'],
#    'id': '1590088695272513537',
#    'text': 'Frau Slomka weilt auf unsere Kosten in Washington, um die midterms zu moderieren. Hätte Herr Thevessen nicht gereicht? #OERR'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37822': {'data': {'edit_history_tweet_ids': ['1590088692374597632'],
#    'id': '1590088692374597632',
#    'text': '@JeffOnTheRight https://t.co/RUMWjfLY8r'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37823': {'data': {'edit_history_tweet_ids': ['1590088695796875267'],
#    'id': '1590088695796875267',
#    'text': '“If we don’t vote, we are ignoring history and giving away the future.”\n\nPat Mitchell\n\n#vote #midterms #quotes'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37824': {'data': {'edit_history_tweet_ids': ['1590088699232292864'],
#    'id': '1590088699232292864',
#    'text': 'RT @GoodPoliticGuy: Absolutely wild how the media, cops and rightwing groups managed to make this a top 2 issue going into the midterms. ht…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37825': {'data': {'edit_history_tweet_ids': ['1590088700658331648'],
#    'id': '1590088700658331648',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37826': {'data': {'edit_history_tweet_ids': ['1590088699706245120'],
#    'id': '1590088699706245120',
#    'text': 'RT @TerryMMcGovern: Happy #ElectionDay! Abortion is on the ballot in 5 states today, and countless congressional, local, and state races ar…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37827': {'data': {'edit_history_tweet_ids': ['1590088700712845312'],
#    'id': '1590088700712845312',
#    'text': 'RT @locuta: Anyhow: ik ga nu nog een paar uur proberen te slapen. Tussen 02:00-05:00 uur doe ik live verslag van de uitslagen van de Amerik…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37828': {'data': {'edit_history_tweet_ids': ['1590088701522358273'],
#    'id': '1590088701522358273',
#    'text': "So Biden's promised all the College kids that if the signed up ago their student loan debt would be forgiven after the midterms !? Didn't they learn he's a liar last time ? He's a hustler and he's just suckering them again for votes today ! https://t.co/hC6mqBrlFe"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37829': {'data': {'edit_history_tweet_ids': ['1590088706547142656'],
#    'id': '1590088706547142656',
#    'text': 'RT @NicholsUprising: Elections aren’t Reality-TV shows. They are complex processes that involve tens of thousands of jurisdictions nationwi…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37830': {'data': {'edit_history_tweet_ids': ['1590088706169282560'],
#    'id': '1590088706169282560',
#    'text': 'RT @melissagira: My Election Day story: on the nationwide movement of self-proclaimed “constitutional sheriffs,” both on the ballot and als…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37831': {'data': {'edit_history_tweet_ids': ['1590088706408734721'],
#    'id': '1590088706408734721',
#    'text': 'Please vote! https://t.co/HCLnPaF4YJ'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37832': {'data': {'edit_history_tweet_ids': ['1590088706891079681'],
#    'id': '1590088706891079681',
#    'text': 'RT @EugeneDaniels2: Trump on DeSantis: “If he did run, I will tell you things about him that won’t be very flattering. I know more about hi…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37833': {'data': {'edit_history_tweet_ids': ['1590088706207014912'],
#    'id': '1590088706207014912',
#    'text': '@JeffOnTheRight Liar'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37834': {'data': {'edit_history_tweet_ids': ['1590088706681344002'],
#    'id': '1590088706681344002',
#    'text': 'RT @MeidasTouch: Let’s talk about the midterms https://t.co/Fu5rzCydAX'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37835': {'data': {'edit_history_tweet_ids': ['1590088708442968064'],
#    'id': '1590088708442968064',
#    'text': 'RT @PPReacaFla2: Para encerrar as fake news "ain o novo congresso dos eua assume amanhã", segue abaixo informações do próprio senado americ…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37836': {'data': {'edit_history_tweet_ids': ['1590088708086456320'],
#    'id': '1590088708086456320',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37837': {'data': {'edit_history_tweet_ids': ['1590088710963761152'],
#    'id': '1590088710963761152',
#    'text': '@BFMTV https://t.co/QXpLYfrCLp'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37838': {'data': {'edit_history_tweet_ids': ['1590088709957111809'],
#    'id': '1590088709957111809',
#    'text': 'RT @JuliaDavisNews: Kremlin cheerleaders hope Republicans win big in the midterms.\n\n"Trump generates a lot of hatred in America’s society..…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37839': {'data': {'edit_history_tweet_ids': ['1590088710330413056'],
#    'id': '1590088710330413056',
#    'text': 'Proud of our VOTE work for The Body Shop. #FLEXYOURVOTE 78% of Gen Z and Millennial-age youth believe the government needs total reform. Also, 2.6% of elected government officials are under 30, so there’s a 97.4% chance young people’s needs come last. \n#Midterms #MidtermElections https://t.co/Tcj2Oq8Du8'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37840': {'data': {'edit_history_tweet_ids': ['1590088712599506946'],
#    'id': '1590088712599506946',
#    'text': 'RT @runews: So Republicans lost the Midterms to voting machines. https://t.co/53DZAK2x4X'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37841': {'data': {'edit_history_tweet_ids': ['1590088713635508225'],
#    'id': '1590088713635508225',
#    'text': 'A taste of things to come? 😵\u200d💫🤬 https://t.co/6STGxWFU6V'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37842': {'data': {'edit_history_tweet_ids': ['1590088715430682624'],
#    'id': '1590088715430682624',
#    'text': "@MayBeHunterF Mail-in ballots are not inherently fraudulent because they are tallied later. Think of it like a cash register. The money from cash payments (in-person votes) is readily avail. The money from CC payments (mail-in ballots) is rec'd later but in no way less valid. False equiv."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37843': {'data': {'edit_history_tweet_ids': ['1590088717414576128'],
#    'id': '1590088717414576128',
#    'text': '@AnnAmericaFirst @dougmastriano @MalcolmOutLoud https://t.co/9ZsTZWNnJB'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37844': {'data': {'edit_history_tweet_ids': ['1590088720673574914'],
#    'id': '1590088720673574914',
#    'text': "RT @SinedWarrior: 1 L'Ukraine s'inquiète du résultat des midterms aux États-Unis. Les républicains préviennent qu’ils ne signeront pas de c…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37845': {'data': {'edit_history_tweet_ids': ['1590088721688190976'],
#    'id': '1590088721688190976',
#    'text': 'why are these midterms killing me 😭'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37846': {'data': {'edit_history_tweet_ids': ['1590088719302033408'],
#    'id': '1590088719302033408',
#    'text': '@JoJoFromJerz Ok and I care why?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37847': {'data': {'edit_history_tweet_ids': ['1590088719821729792'],
#    'id': '1590088719821729792',
#    'text': 'RT @BethRigby: Musk’s intervention ahead of midterms 1st time big social media CEO explicitly taken a side. He’d previously argued Twitter…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37848': {'data': {'edit_history_tweet_ids': ['1590088720837152769'],
#    'id': '1590088720837152769',
#    'text': 'RT @tvlofficiel: [Politique]🇺🇸🗳 Le sénateur Ted #Cruz (Parti Républicain) sur les #Midterms : "Je pense que cela va être, pas seulement une…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37849': {'data': {'edit_history_tweet_ids': ['1590088721105584130'],
#    'id': '1590088721105584130',
#    'text': 'Stroke time...🤣🤣🤣🤣 https://t.co/gE6JvHyW9t'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37850': {'data': {'edit_history_tweet_ids': ['1590088724490366976'],
#    'id': '1590088724490366976',
#    'text': 'RT @ChrisPlanteShow: From the good people at @Newsbusters: Voter Suppression: ABC, CBS Cast Doubt on Midterms, Blaming Violent Right-Winger…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37851': {'data': {'edit_history_tweet_ids': ['1590088725052403712'],
#    'id': '1590088725052403712',
#    'text': 'RT @Forbes: Musk Breaks ‘Politically Neutral’ Twitter Promise After Endorsing Republicans In Midterms https://t.co/KMqbzWkd67 https://t.co/…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37852': {'data': {'edit_history_tweet_ids': ['1590088726407188480'],
#    'id': '1590088726407188480',
#    'text': '🙏 https://t.co/ANCQXtJXeM'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37853': {'data': {'edit_history_tweet_ids': ['1590088728898592768'],
#    'id': '1590088728898592768',
#    'text': 'RT @RonFilipkowski: It’s that time again! Time for my closing argument before the midterms. If this is what a majority of Americans want, G…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37854': {'data': {'edit_history_tweet_ids': ['1590088730408210432'],
#    'id': '1590088730408210432',
#    'text': 'RT @ardenthistorian: Wahltag, das Signal für diverses "was kümmerst du dich um die USA kümmer dich lieber um Deutschland" Gepöbele. Sweet p…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37855': {'data': {'edit_history_tweet_ids': ['1590088731570364416'],
#    'id': '1590088731570364416',
#    'text': "RT @JeffOnTheRight: I'm in line to vote.\n\nFinally.\n\nHad to fight my way through groups of MAGA hat-wearing Republicans trying to stop me.…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37856': {'data': {'edit_history_tweet_ids': ['1590088731947847680'],
#    'id': '1590088731947847680',
#    'text': "@SameeraKhan so if republicans win it's because they rigged the election?"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37857': {'data': {'edit_history_tweet_ids': ['1590088732530868224'],
#    'id': '1590088732530868224',
#    'text': '@JeffOnTheRight show video proof that this occurred'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37858': {'data': {'edit_history_tweet_ids': ['1590088738843267072'],
#    'id': '1590088738843267072',
#    'text': '@itzjoshuajake Yeah that’s because big money cashed out from there crypto profits and put it into stocks. Remember crypto is the only game in town when it’s the weekend especially a few days from elections.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37859': {'data': {'edit_history_tweet_ids': ['1590088735911137280'],
#    'id': '1590088735911137280',
#    'text': 'Whatever happens with the #Midterms, saving American democracy requires that journalists &amp; others with a public platform tell the American people not what they want to hear but the uncomfortable things they need to hear. I explain more in my new @Salon:\n\nhttps://t.co/EZY3YrrIO1'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37860': {'data': {'edit_history_tweet_ids': ['1590088735563329536'],
#    'id': '1590088735563329536',
#    'text': '@PaulBongiorno True, it is unbelievably horrible 😬😵\u200d💫😱'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37861': {'data': {'edit_history_tweet_ids': ['1590088742349701120'],
#    'id': '1590088742349701120',
#    'text': 'RT @thehill: Howard Stern: Preserving democracy is "the only f—ing issue on the table" in midterms https://t.co/G1QJwMznoh https://t.co/Dra…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37862': {'data': {'edit_history_tweet_ids': ['1590088741338898432'],
#    'id': '1590088741338898432',
#    'text': '@JoyceWhiteVance @MuellerSheWrote My polling place was packed here in Southern Alabama. Made me happy 💙'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37863': {'data': {'edit_history_tweet_ids': ['1590088743247294465'],
#    'id': '1590088743247294465',
#    'text': "RT @ddanpereira: Rachel Maddow, Joy Reid &amp; Nicolle Wallace along with Lawrence O'Donnell &amp; Steve Kornacki will cover the #Midterms on #MSNB…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37864': {'data': {'edit_history_tweet_ids': ['1590088741863182336'],
#    'id': '1590088741863182336',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37865': {'data': {'edit_history_tweet_ids': ['1590088741783502848'],
#    'id': '1590088741783502848',
#    'text': '@RealSaavedra How fucking stupid.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37866': {'data': {'edit_history_tweet_ids': ['1590088746099433474'],
#    'id': '1590088746099433474',
#    'text': 'RT @DaddyDragon15: Americans are voting for the Constitution and wearing English Constitution Party badges.  I Love America (and beautiful…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37867': {'data': {'edit_history_tweet_ids': ['1590088745524793344'],
#    'id': '1590088745524793344',
#    'text': 'RT @MeidasTouch: Let’s talk about the midterms https://t.co/Fu5rzCydAX'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37868': {'data': {'edit_history_tweet_ids': ['1590088745143128064'],
#    'id': '1590088745143128064',
#    'text': 'RT @MarekMeissner: Tak więc niezależnie od tego kto wygra w midterms, powinniśmy mieć nadzieję, że wygrają ci, którzy nie osłabią pomocy dl…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37869': {'data': {'edit_history_tweet_ids': ['1590088748808953856'],
#    'id': '1590088748808953856',
#    'text': '@TonyMaciulis @JoeConchaTV Grow a sack.  These puff pieces on Twitter don’t fly like they previously did.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37870': {'data': {'edit_history_tweet_ids': ['1590088749547155456'],
#    'id': '1590088749547155456',
#    'text': 'RT @Cernovich: Friend made a good point about tomorrow. Democrats need to save their cheating for 2024. As ass kicking tomorrow gives centr…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37871': {'data': {'edit_history_tweet_ids': ['1590088747785531392'],
#    'id': '1590088747785531392',
#    'text': "Let us write your;\nResearch paper due\nDiscussion board\nDissertation\nFall semester\nEssay pay\nLiterature\nOnline classes\nCourse work \nProposal\nSomeone write.\nExam\nTests /quizzes\nDiscussion post\nMidterms \nHmu for A's\nDm @SmithEssays"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37872': {'data': {'edit_history_tweet_ids': ['1590088748720525312'],
#    'id': '1590088748720525312',
#    'text': '@OANN North Pole needs her'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37873': {'data': {'edit_history_tweet_ids': ['1590088749609672704'],
#    'id': '1590088749609672704',
#    'text': "RT @FrancoisF24: Where violent rhetoric leads...\nStrong views on #Midterms &amp; the direction of U.S. democracy 🇺🇸🗳️: \n@uvsq's Cécile Coquet-M…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37874': {'data': {'edit_history_tweet_ids': ['1590088751761719297'],
#    'id': '1590088751761719297',
#    'text': '@JeffOnTheRight Stay strong! That Jim Crow 2.0 is pretty crazy.   Making more people vote and all 😂😂'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37875': {'data': {'edit_history_tweet_ids': ['1590088749974573057'],
#    'id': '1590088749974573057',
#    'text': 'RT @Hamletgarcia17: Here you go and Democrats want to make people believe That America will cast their vote on abortion. This election is a…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37876': {'data': {'edit_history_tweet_ids': ['1590088748376563712'],
#    'id': '1590088748376563712',
#    'text': 'Probably won’t be forTrudeau to decide..🤣🤣🤣 https://t.co/qoHvBmo9it'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37877': {'data': {'edit_history_tweet_ids': ['1590088752608968705'],
#    'id': '1590088752608968705',
#    'text': 'RT @Deborah53010: @selfPmade @RSBNetwork @LizWillis_ PatriciaC you must be a liberal democrat.   We all know that the 2020 election was sto…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37878': {'data': {'edit_history_tweet_ids': ['1590088750457290754'],
#    'id': '1590088750457290754',
#    'text': '@JeffOnTheRight No fucking way that happened'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37879': {'data': {'edit_history_tweet_ids': ['1590088751036141569'],
#    'id': '1590088751036141569',
#    'text': '@Stuzipants @ScottBentonMP hang your head in shame'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37880': {'data': {'edit_history_tweet_ids': ['1590088753803972608'],
#    'id': '1590088753803972608',
#    'text': 'RT @Vpauline006: États-Unis 🇺🇸 La triche en direct  à Philadelphie, en Pennsylvanie. #Midterms Q 🐸😳\U0001fae3🥴 https://t.co/S8Vs98zQOG'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37881': {'data': {'edit_history_tweet_ids': ['1590088752273424384'],
#    'id': '1590088752273424384',
#    'text': 'RT @Vpauline006: États-Unis 🇺🇸 La triche en direct  à Philadelphie, en Pennsylvanie. #Midterms Q 🐸😳\U0001fae3🥴 https://t.co/S8Vs98zQOG'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37882': {'data': {'edit_history_tweet_ids': ['1590088755398184960'],
#    'id': '1590088755398184960',
#    'text': '@StevenBeschloss "Maybe not?"'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37883': {'data': {'edit_history_tweet_ids': ['1590088751241662464'],
#    'id': '1590088751241662464',
#    'text': '@JeffOnTheRight @PolitiBunny OMG.  Sometimes the jokes are so close to reality you don’t get it.  Good, Jeff.  Let’s go destroy democracy by voting!'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37884': {'data': {'edit_history_tweet_ids': ['1590088755503075328'],
#    'id': '1590088755503075328',
#    'text': 'On Election Day. Trump says this. https://t.co/JsOe1DizLD'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37885': {'data': {'edit_history_tweet_ids': ['1590088756668743681'],
#    'id': '1590088756668743681',
#    'text': 'Chris Nijhuis is verhinderd het AC over de midterms te geven woensdag van 12.30 - 13.15 uur in de hal van het Erasmusgebouw. Hij wordt vervangen door Peter van der Heiden. https://t.co/vxzQl8o8br'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37886': {'data': {'edit_history_tweet_ids': ['1590088758845919234'],
#    'id': '1590088758845919234',
#    'text': '@TheophanesRex Depends on how the midterms shake out.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37887': {'data': {'edit_history_tweet_ids': ['1590088756908142593'],
#    'id': '1590088756908142593',
#    'text': "RT @F2Washington: 🗳 En ce jour de #midterms, difficile de prédire les futurs résultats aux États-Unis 🇺🇸\n\nEn cause : les millions d'électeu…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37888': {'data': {'edit_history_tweet_ids': ['1590088757642166274'],
#    'id': '1590088757642166274',
#    'text': '@JeffOnTheRight LIAR!!'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37889': {'data': {'edit_history_tweet_ids': ['1590088757390487554'],
#    'id': '1590088757390487554',
#    'text': 'Ang gusto ko lang ngayon makapasa sa midterms 😭'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37890': {'data': {'edit_history_tweet_ids': ['1590088757075922944'],
#    'id': '1590088757075922944',
#    'text': "I don't believe one word of that. You're a liar. https://t.co/K71lbenLZf"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37891': {'data': {'edit_history_tweet_ids': ['1590088759315660801'],
#    'id': '1590088759315660801',
#    'text': 'Misinformation floods the midterms, at times urging violence https://t.co/y9w9njMHQb'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37892': {'data': {'edit_history_tweet_ids': ['1590088760209076225'],
#    'id': '1590088760209076225',
#    'text': '@JeffOnTheRight https://t.co/dgrUKJ8enU'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37893': {'data': {'edit_history_tweet_ids': ['1590088758270955520'],
#    'id': '1590088758270955520',
#    'text': 'RT @EdRaposo_: As midterms americanas desse ano provam a mutreta presidencial de 2020 da mesma maneira que o primeiro turno daqui, eleições…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37894': {'data': {'edit_history_tweet_ids': ['1590088763564118018'],
#    'id': '1590088763564118018',
#    'text': '@AriDrennen @anyazoledz Anti electoralism is transphobic and racist https://t.co/fd1InpeVL9'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37895': {'data': {'edit_history_tweet_ids': ['1590088761735528450'],
#    'id': '1590088761735528450',
#    'text': 'You voted!\n\nSo, what’s next? \n\nCome join @disabilityrightsca @donetworkorg @calscdd @cfilc_1982 on November 10th at 1:30 P.M. for a free webinar about what happens AFTER the #midterms are over. \n\nPlease register at: https://t.co/fkaOKLxXb2 https://t.co/tC3A4wIhWG'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37896': {'data': {'edit_history_tweet_ids': ['1590088761643503622'],
#    'id': '1590088761643503622',
#    'text': 'RT @kingojungle: Just a reminder in case you don’t think your midterm vote matters. If conservatives win the midterms Biden will be impeach…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37897': {'data': {'edit_history_tweet_ids': ['1590088760536215552'],
#    'id': '1590088760536215552',
#    'text': 'RT @courtney_manna: I voted!! A poll worker said he thinks it’s already a bigger turnout for midterms today than it was for the 2020 Presid…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37898': {'data': {'edit_history_tweet_ids': ['1590088761173770242'],
#    'id': '1590088761173770242',
#    'text': ".@daveweigel takes a look at some of the burning political questions tonight's results will finally answer  #ElectionDay   https://t.co/w7nj2ny7hI"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37899': {'data': {'edit_history_tweet_ids': ['1590088760762720256'],
#    'id': '1590088760762720256',
#    'text': 'RT @JansingReports: “Close races, you win those not by more T.V. ads, but you win them with very very strong ‘get out the vote’ operations…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37900': {'data': {'edit_history_tweet_ids': ['1590088764554383363'],
#    'id': '1590088764554383363',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37901': {'data': {'edit_history_tweet_ids': ['1590088766039142402'],
#    'id': '1590088766039142402',
#    'text': '@JeffOnTheRight More democrats spreading election lies.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37902': {'data': {'edit_history_tweet_ids': ['1590088767632998403'],
#    'id': '1590088767632998403',
#    'text': '@JeffOnTheRight Jim crow was the party of Democrats but good luck with that 😂'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37903': {'data': {'edit_history_tweet_ids': ['1590088766555054080'],
#    'id': '1590088766555054080',
#    'text': 'RT @whatgives1313: Has Fox called the midterms for the Democrats yet?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37904': {'data': {'edit_history_tweet_ids': ['1590088763329642496'],
#    'id': '1590088763329642496',
#    'text': 'RT @joeabodnar: Seeing an expected uptick in Russian propaganda about the midterms. Both state media and officials are casting doubt on the…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37905': {'data': {'edit_history_tweet_ids': ['1590088768866111488'],
#    'id': '1590088768866111488',
#    'text': '@bcatini Democratas provavelmente manterão o Senado'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37906': {'data': {'edit_history_tweet_ids': ['1590088768656404481'],
#    'id': '1590088768656404481',
#    'text': 'Donne argent https://t.co/5MI7x68et6'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37907': {'data': {'edit_history_tweet_ids': ['1590088769549762560'],
#    'id': '1590088769549762560',
#    'text': "@TechCharts Been buying for past hour. Cautiously waiting for after midterms. Looks kinda like the 'auto-correct' is already being priced in. Mostly thx to news on FTX/FTT. SOL got hit hard bc of the FTT investors' connection to SOL. Solana is still one of the best L1! &gt;ETH?"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37908': {'data': {'edit_history_tweet_ids': ['1590088771223322624'],
#    'id': '1590088771223322624',
#    'text': '@JeffOnTheRight LOL\nJesse? Is that you?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37909': {'data': {'edit_history_tweet_ids': ['1590088769490673664'],
#    'id': '1590088769490673664',
#    'text': '@JeffOnTheRight Ill take shit that didnt happen for 200,  alex'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37910': {'data': {'edit_history_tweet_ids': ['1590088774607728640'],
#    'id': '1590088774607728640',
#    'text': '#Biden connected👇#Midterm2022 #Midterms2022 #Midterms #Vote #GOP #freedom #VoteBlueIn2022 #VoteBlueForDemocracy #VoteRed2022 #VoteBlue #VoteBlueToSaveAmerica #VoteBlueToday #Bidenflation #trump #ElectionDay #ElectionDay2022 #MAGA #USA #elections #election #voting #votetoday https://t.co/cU1mDQ6IJZ'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37911': {'data': {'edit_history_tweet_ids': ['1590088776428457984'],
#    'id': '1590088776428457984',
#    'text': 'RT @chavodeltoro: Fogoso se levanta, si bien él es considerado por un gran número de mexicanos que radican en Morena como el 2do líder mund…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37912': {'data': {'edit_history_tweet_ids': ['1590088774901727234'],
#    'id': '1590088774901727234',
#    'text': '@drboycewatkins1 Dr Boyce they still won’t bc they still negropeans riding their coat tails to hell'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37913': {'data': {'edit_history_tweet_ids': ['1590088774440321025'],
#    'id': '1590088774440321025',
#    'text': 'RT @2_bloempje: Draadje: 8-11 Maar van #electionfraude is uiteraard geen sprake. Die meneer is kiezers die een verkeerde keuze maakten alle…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37914': {'data': {'edit_history_tweet_ids': ['1590088776281624576'],
#    'id': '1590088776281624576',
#    'text': '@SerenaVogel Ha! okay that makes more sense'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37915': {'data': {'edit_history_tweet_ids': ['1590088775962857473'],
#    'id': '1590088775962857473',
#    'text': 'RT @NicholsUprising: Think every election will be settled tonight. That’s never been the case before and it won’t be this year. With close…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37916': {'data': {'edit_history_tweet_ids': ['1590088776063541249'],
#    'id': '1590088776063541249',
#    'text': 'RT @Styx666Official: Soon I will relocate to my temporary studio/vacation center.\n\nReminder that the day after midterms I will probably do…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37917': {'data': {'edit_history_tweet_ids': ['1590088773580488704'],
#    'id': '1590088773580488704',
#    'text': '@JeffOnTheRight Stop with your bull shit.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37918': {'data': {'edit_history_tweet_ids': ['1590088776323563521'],
#    'id': '1590088776323563521',
#    'text': '@smh Crazy headline.  So only voting for one party is democracy.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37919': {'data': {'edit_history_tweet_ids': ['1590088784657645571'],
#    'id': '1590088784657645571',
#    'text': '#Biden makes bold announcement on fate of coal miners ahead of midterms https://t.co/avArbwQfxu'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37920': {'data': {'edit_history_tweet_ids': ['1590088782396944384'],
#    'id': '1590088782396944384',
#    'text': "@BidensWins So Biden's promised all the College kids that if the signed up ago their student loan debt would be forgiven after the midterms !? Didn't they learn he's a liar last time ? He's a hustler and he's just suckering them again for votes today !"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37921': {'data': {'edit_history_tweet_ids': ['1590088784741560321'],
#    'id': '1590088784741560321',
#    'text': '@JamesAALongman I think it may be to distinguish them from the many not openly gay candidates, even more depressingly (I agree, btw)'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37922': {'data': {'edit_history_tweet_ids': ['1590088785148403712'],
#    'id': '1590088785148403712',
#    'text': "@JeffOnTheRight @CAShariRocks I remember when I voted early here in Texas a couple weeks ago and they asked for an ID. I accidentally pulled out my white privilege card instead of my driver's license, but the poll workers gladly accepted that."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37923': {'data': {'edit_history_tweet_ids': ['1590088785588498433'],
#    'id': '1590088785588498433',
#    'text': '@MichelleObama @WhenWeAllVote Please run for president!!\nNo dought you will win. Please save us'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37924': {'data': {'edit_history_tweet_ids': ['1590088785471344640'],
#    'id': '1590088785471344640',
#    'text': "RT @Reuters: Elon Musk, Twitter's new owner, urged Americans to elect a Republican Congress in U.S. midterms to counterbalance President Jo…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37925': {'data': {'edit_history_tweet_ids': ['1590088786884853760'],
#    'id': '1590088786884853760',
#    'text': '@JeffOnTheRight Ok Juicy Smolié 2.0'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37926': {'data': {'edit_history_tweet_ids': ['1590088788268961793'],
#    'id': '1590088788268961793',
#    'text': "@CTVNews Don't forget about the Senate."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37927': {'data': {'edit_history_tweet_ids': ['1590088787794989056'],
#    'id': '1590088787794989056',
#    'text': 'RT @BOROWSKIMIKE: Elections "midterms" américaines d\'après les derniers sondages les républicains de Donald Trump gagneraient 84 sièges sur…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37928': {'data': {'edit_history_tweet_ids': ['1590088787300077568'],
#    'id': '1590088787300077568',
#    'text': "@rustyrockets @rumblevideo Let's see what happens? 🤣 https://t.co/ERgYpOHL8u"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37929': {'data': {'edit_history_tweet_ids': ['1590088792358076416'],
#    'id': '1590088792358076416',
#    'text': 'RT @kylegriffin1: Rep. James Clyburn to Fox: "Democracy will be ending" if Democrats lose the midterms.\n\n"I\'ve studied history all of my li…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37930': {'data': {'edit_history_tweet_ids': ['1590088792597487616'],
#    'id': '1590088792597487616',
#    'text': 'RT @cryptorecruitr: - S&amp;P 500 green\n- DXY falling\n- Potential red wave in midterms\n\nI wouldn’t be surprised if #crypto bounces hard.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37931': {'data': {'edit_history_tweet_ids': ['1590088791892819968'],
#    'id': '1590088791892819968',
#    'text': '@FoxNews This stupidity must end and that actor of a  president will not get my support'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37932': {'data': {'edit_history_tweet_ids': ['1590088790768775168'],
#    'id': '1590088790768775168',
#    'text': "RT @F2Washington: 🗳 En ce jour de #midterms, difficile de prédire les futurs résultats aux États-Unis 🇺🇸\n\nEn cause : les millions d'électeu…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37933': {'data': {'edit_history_tweet_ids': ['1590088794807554048'],
#    'id': '1590088794807554048',
#    'text': 'RT @ParkerMolloy: Hey, in the off-chance that all that was keeping you from casting a ballot in the midterms was the urging of a mid-tier n…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37934': {'data': {'edit_history_tweet_ids': ['1590088794031927296'],
#    'id': '1590088794031927296',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37935': {'data': {'edit_history_tweet_ids': ['1590088795428618241'],
#    'id': '1590088795428618241',
#    'text': "RT @TheChrisWinters: These #Midterms2022 are probably the most important midterms we've had in modern history, and they'll have a direct im…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '37936': {'data': {'edit_history_tweet_ids': ['1590088795827089408'],
#    'id': '1590088795827089408',
# ...
#    'text': "@clairecmc I'm likely hoping what you're hoping, but yeah, midterms do tend to go to The Other Party, so could be. But hope is the thing with feathers..."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38732': {'data': {'edit_history_tweet_ids': ['1590089599858376706'],
#    'id': '1590089599858376706',
#    'text': '@JoyceWhiteVance @noneegrey @Patribotics Alabama💙'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38733': {'data': {'edit_history_tweet_ids': ['1590089599698599936'],
#    'id': '1590089599698599936',
#    'text': 'RT @Vpauline006: États-Unis 🇺🇸 La triche en direct  à Philadelphie, en Pennsylvanie. #Midterms Q 🐸😳\U0001fae3🥴 https://t.co/S8Vs98zQOG'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38734': {'data': {'edit_history_tweet_ids': ['1590089600604962816'],
#    'id': '1590089600604962816',
#    'text': "If we don't  win these midterms there will be a Russian flag flying over Washington https://t.co/U2sbwePUP6"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38735': {'data': {'edit_history_tweet_ids': ['1590089602282721280'],
#    'id': '1590089602282721280',
#    'text': 'RT @StevenBeschloss: One note before the midterms: Nov. 9 would be a fine day for Merrick Garland to indict Donald J. Trump for crimes rela…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38736': {'data': {'edit_history_tweet_ids': ['1590089604933505024'],
#    'id': '1590089604933505024',
#    'text': '@USArmy seriously this is the face you want of the USArmy?I\nhttps://t.co/z7J3nxdHlS'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38737': {'data': {'edit_history_tweet_ids': ['1590089605591625728'],
#    'id': '1590089605591625728',
#    'text': '@JeffOnTheRight Thots and players'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38738': {'data': {'edit_history_tweet_ids': ['1590089604321128448'],
#    'id': '1590089604321128448',
#    'text': "@kylegriffin1 That's terrific!  We have more than our share of gun toting RW 3 Percenters, White Supremacists Oathkeepers, and KKK nutjobs."},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38739': {'data': {'edit_history_tweet_ids': ['1590089604996419584'],
#    'id': '1590089604996419584',
#    'text': '@realTuckFrumper Palm Beach is in mandatory evacuation.   Mara la go  away.  Hurricane is headed straight there!   Sorry for others though'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38740': {'data': {'edit_history_tweet_ids': ['1590089609522089984'],
#    'id': '1590089609522089984',
#    'text': 'RT @mitchellreports: Tom Bonier: Increased gender gap in early vote is an ‘early sign’ of abortion’s role in 2022 midterms @tbonier @Cecile…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38741': {'data': {'edit_history_tweet_ids': ['1590089607667818496'],
#    'id': '1590089607667818496',
#    'text': 'RT @brianstelter: Trump calls DeSantis "our competitor" and says "I think if he runs he could hurt himself very badly." Says it would be a…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38742': {'data': {'edit_history_tweet_ids': ['1590089608213065728'],
#    'id': '1590089608213065728',
#    'text': 'RT @NicholsUprising: 71% of Americans view unions favorably. Yet, joining a union and engaging in collective bargaining is made difficult b…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38743': {'data': {'edit_history_tweet_ids': ['1590089615255670785'],
#    'id': '1590089615255670785',
#    'text': "RT @JoyceWhiteVance: My polling place is never crowded at midterms. I've been voting here for 30+ years. Today, in Alabama, with no contest…"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38744': {'data': {'edit_history_tweet_ids': ['1590089613359517697'],
#    'id': '1590089613359517697',
#    'text': 'Make sure to follow this story &amp; ALL the election results tonight #ElectionDay on @NewsNation !!\n\nhttps://t.co/C4kGeyaWch'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38745': {'data': {'edit_history_tweet_ids': ['1590089614160982017'],
#    'id': '1590089614160982017',
#    'text': "Votes cast in these elections will determine control of the House and Senate. Plus, we'll give updates on key state and local races. https://t.co/ZZe5JiANAU"},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38746': {'data': {'edit_history_tweet_ids': ['1590089616370999296'],
#    'id': '1590089616370999296',
#    'text': 'RT @kingojungle: Just a reminder in case you don’t think your midterm vote matters. If conservatives win the midterms Biden will be impeach…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38747': {'data': {'edit_history_tweet_ids': ['1590089614374866944'],
#    'id': '1590089614374866944',
#    'text': '@locuta @NPORadio1 Laat je tussendoor hier ook wat doordruppelen?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38748': {'data': {'edit_history_tweet_ids': ['1590089617134407681'],
#    'id': '1590089617134407681',
#    'text': 'The 20 counties that will decide the midterms (@politico / Politico)\n\nhttps://t.co/8IKEQtFvbi\nhttps://t.co/9J9bsPlGoI'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38749': {'data': {'edit_history_tweet_ids': ['1590089616086142977'],
#    'id': '1590089616086142977',
#    'text': 'RT @JonathanTurley: ...Courts have the authority to extend hours if voting is delayed by such malfunctions. Secretary of State Katie Hobbs…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38750': {'data': {'edit_history_tweet_ids': ['1590089619512913922'],
#    'id': '1590089619512913922',
#    'text': 'RT @OANN: Keep up to date with the Midterm Elections today with OAN Live! OAN Live will cover all the key state Midterms with reliable accu…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38751': {'data': {'edit_history_tweet_ids': ['1590089619810680832'],
#    'id': '1590089619810680832',
#    'text': 'RT @MarkJacob16: The results of the midterms are still to come, but one big loser was political news coverage. So much horse race, such sha…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38752': {'data': {'edit_history_tweet_ids': ['1590089620033015809'],
#    'id': '1590089620033015809',
#    'text': 'RT @mz_storymakers: Für die Demokraten von #Biden ist die Demokratie in Gefahr, wenn sich die Wählenden in freien demokratischen Wahlen für…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38753': {'data': {'edit_history_tweet_ids': ['1590089621807206401'],
#    'id': '1590089621807206401',
#    'text': 'RT @chavodeltoro: Fogoso se levanta, si bien él es considerado por un gran número de mexicanos que radican en Morena como el 2do líder mund…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38754': {'data': {'edit_history_tweet_ids': ['1590089621320310787'],
#    'id': '1590089621320310787',
#    'text': 'RT @ComicDaveSmith: I still can’t shake this bizarre feeling about Biden’s closing pitch ahead of the midterms. He said there’s going to be…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38755': {'data': {'edit_history_tweet_ids': ['1590089621337436160'],
#    'id': '1590089621337436160',
#    'text': 'RT @mitchellreports: Tom Bonier: Increased gender gap in early vote is an ‘early sign’ of abortion’s role in 2022 midterms @tbonier @Cecile…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38756': {'data': {'edit_history_tweet_ids': ['1590089623782686720'],
#    'id': '1590089623782686720',
#    'text': '@FoxNews No more money for Ukraine will be great to focus on the USA and its citizens.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38757': {'data': {'edit_history_tweet_ids': ['1590089623644274688'],
#    'id': '1590089623644274688',
#    'text': 'RT @carolynryan: “If he did run, I will tell you things about him that won’t be very flattering. I know more about him than anybody other t…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38758': {'data': {'edit_history_tweet_ids': ['1590089627062657024'],
#    'id': '1590089627062657024',
#    'text': '@Reuters Love it. Smart man!'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38759': {'data': {'edit_history_tweet_ids': ['1590089627171696640'],
#    'id': '1590089627171696640',
#    'text': '@EugeneDaniels2 Did your Trump vote for your Desantis?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38760': {'data': {'edit_history_tweet_ids': ['1590089632100020225'],
#    'id': '1590089632100020225',
#    'text': 'Hoje são as midterms nos EUA e as minhas expectativas estão tão baixas que já me dou por contente se os Democratas não tiverem uma noite completamente desastrosa'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38761': {'data': {'edit_history_tweet_ids': ['1590089632615919617'],
#    'id': '1590089632615919617',
#    'text': 'RT @darafaye: Jesus said unto thee “Voteith like your uterus depends on it because it doesith.” \n\nAnd all the women did. \n\nMidterms 11:08'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38762': {'data': {'edit_history_tweet_ids': ['1590089629633761280'],
#    'id': '1590089629633761280',
#    'text': 'RT @QJeulin: #DonaldTrump lors de l\'un de ses discours avant les #Midterms:\n➡️ "Nous allons remettre en place une éducation patriote dans n…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38763': {'data': {'edit_history_tweet_ids': ['1590089632267784193'],
#    'id': '1590089632267784193',
#    'text': 'RT @Vpauline006: États-Unis 🇺🇸 La triche en direct  à Philadelphie, en Pennsylvanie. #Midterms Q 🐸😳\U0001fae3🥴 https://t.co/S8Vs98zQOG'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38764': {'data': {'edit_history_tweet_ids': ['1590089636650811392'],
#    'id': '1590089636650811392',
#    'text': 'RT @CNN: .@JohnKingCNN explains why this is the most complicated midterms election of his four-decades long career, and why no one should m…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38765': {'data': {'edit_history_tweet_ids': ['1590089636210429954'],
#    'id': '1590089636210429954',
#    'text': '@L_ThinkTank Vous parlez de ce qui se passe en Arizona, Nj et ailleurs ??'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38766': {'data': {'edit_history_tweet_ids': ['1590089636960944131'],
#    'id': '1590089636960944131',
#    'text': '@CBSNewsPress @CBSNews @people @NorahODonnell @GayleKing @margbrennan @vladduthiersCBS Why can’t we have a fair election? https://t.co/LL8INXmpFu'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38767': {'data': {'edit_history_tweet_ids': ['1590089639247110144'],
#    'id': '1590089639247110144',
#    'text': 'No One Forced Republicans to Do Any of These Things https://t.co/eXpxfNbBSB'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38768': {'data': {'edit_history_tweet_ids': ['1590089642451533824'],
#    'id': '1590089642451533824',
#    'text': 'RT @CNN: Races in Pennsylvania, Georgia, Arizona, Wisconsin and Nevada could decide the future of the US Senate in this year’s midterms.\n\nL…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38769': {'data': {'edit_history_tweet_ids': ['1590089642304765952'],
#    'id': '1590089642304765952',
#    'text': '@ComicDaveSmith If you look at the massive Democrat fraud underway w sabotaged voting machines in @GOP areas of Maricopa county know why. @FoxBusiness @FoxNews @CNNPolitics @MSNBC'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38770': {'data': {'edit_history_tweet_ids': ['1590089641574924288'],
#    'id': '1590089641574924288',
#    'text': '@JeffOnTheRight Did they hang a "noose" on your neck and sprinkle you with bleach?\nAlso, by any chance did you get a good look at them and did they look like they might be from Nigeria?'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38771': {'data': {'edit_history_tweet_ids': ['1590089644368334848'],
#    'id': '1590089644368334848',
#    'text': 'https://t.co/4brByC9kpR'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38772': {'data': {'edit_history_tweet_ids': ['1590089645035245568'],
#    'id': '1590089645035245568',
#    'text': '@Reuters People are all bent, when everyone knows all Facebook, Google, NBC, CNN….countless CEOs all vote Blue. @elonmusk says vote Red and every liberal is #triggered.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38773': {'data': {'edit_history_tweet_ids': ['1590089647912546304'],
#    'id': '1590089647912546304',
#    'text': 'RT @TimInHonolulu: 3. likely simply because, if he is charged with Jan 6 crimes in addition to espionage, his incitement of violence during…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38774': {'data': {'edit_history_tweet_ids': ['1590089645584707584'],
#    'id': '1590089645584707584',
#    'text': 'Feel free to share &amp; pass this book around as you wish \n\nin preparation for the existentially important Midterm elections.\n\nOur very lives, not to mention our freedom &amp; democracy, are on the line like no other time\n\nREAD/DWL BOOK... https://t.co/FwZMIjaRHx #Midterms\n\nCW22 Pf/318'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38775': {'data': {'edit_history_tweet_ids': ['1590089647115628546'],
#    'id': '1590089647115628546',
#    'text': '@JeffOnTheRight LIAR'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38776': {'data': {'edit_history_tweet_ids': ['1590089650143916032'],
#    'id': '1590089650143916032',
#    'text': 'RT @halltoons: Let’s vote stupid out. #ElectionDay #Midterms2022 #Midterms #vote #elections @CartooningPeace @jaketapper @co_rapunzel4 @1mi…'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38777': {'data': {'edit_history_tweet_ids': ['1590089653264470016'],
#    'id': '1590089653264470016',
#    'text': '@AriMelber An aviation as made by the instructions here: https://t.co/CJKdFmZdPe'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38778': {'data': {'edit_history_tweet_ids': ['1590089652845031424'],
#    'id': '1590089652845031424',
#    'text': 'Leaving this 🧵 here so I can keep coming back to it after the midterms. https://t.co/rE9xuvWCXR'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38779': {'data': {'edit_history_tweet_ids': ['1590089652299476992'],
#    'id': '1590089652299476992',
#    'text': 'Boah, bewegt mal jemand die Uhr schneller, ich will dass die Midterms endlich vorbei sind. \n\nAlternativ haltet die Uhr an und lasst sie niemals stattfinden. Ich hätte gerne einen entspannten Endlosabend.'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38780': {'data': {'edit_history_tweet_ids': ['1590089651834212353'],
#    'id': '1590089651834212353',
#    'text': '@FranckenTheo Eindelijk! Maar 4% voor klimaathysterie! Nog 4 teveel toch…..'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  '38781': {'data': {'edit_history_tweet_ids': ['1590089655726530561'],
#    'id': '1590089655726530561',
#    'text': 'RT @AlevelPoliticsR: BBC News - US midterms: When will we know the election results?\nhttps://t.co/7IBHbD8V2B'},
#   'matching_rules': [{'id': '1590047576933687297', 'tag': 'election'}]},
#  ...}
