# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %config InlineBackend.figure_format = "retina"

# %%
sns.set_context("talk")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %config InlineBackend.figure_format = "retina"
sns.set_context("talk")

import warnings
warnings.filterwarnings("ignore")

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
fig_num = 1
print(f'this figure is {fig_num}')
fig_num += 1
print(f'this figure is {fig_num}')
# Out:
# this figure is 1
# this figure is 2

# %%
df = pd.DataFrame({'New York': [25]})

# %%
df
# Out:
#    New York
# 0        25

# %%
df.melt()
# Out:
#    variable  value
# 0  New York     25

# %%
df = pd.DataFrame({'New York': [25], 'Paris': [27], 'London': [30]})

# %%
df
# Out:
#    New York  Paris  London
# 0        25     27      30

# %%
df.melt()
# Out:
#    variable  value
# 0  New York     25
# 1     Paris     27
# 2    London     30

# %%
df = pd.DataFrame({
    'New York': [25, 27, 23, 25, 29],
    'Paris': [27, 22, 24, 26, 28],
    'London': [30, 31, 33, 29, 25]})

# %%
df
# Out:
#    New York  Paris  London
# 0        25     27      30
# 1        27     22      31
# 2        23     24      33
# 3        25     26      29
# 4        29     28      25

# %%
df.melt()
# Out:
#     variable  value
# 0   New York     25
# 1   New York     27
# 2   New York     23
# 3   New York     25
# 4   New York     29
# 5      Paris     27
# 6      Paris     22
# 7      Paris     24
# 8      Paris     26
# 9      Paris     28
# 10    London     30
# 11    London     31
# 12    London     33
# 13    London     29
# 14    London     25

# %%
df.melt(var_name="city", value_name="temperature")
# Out:
#         city  temperature
# 0   New York           25
# 1   New York           27
# 2   New York           23
# 3   New York           25
# 4   New York           29
# 5      Paris           27
# 6      Paris           22
# 7      Paris           24
# 8      Paris           26
# 9      Paris           28
# 10    London           30
# 11    London           31
# 12    London           33
# 13    London           29
# 14    London           25

# %%
temperatures = pd.DataFrame({
    'city': ['New York', 'London', 'Paris', 'Berlin', 'Amsterdam'],
    'day1' : [23, 25, 27, 26, 24],
    'day2' : [22, 21, 25, 26, 23],
    "day3": [26, 25, 24, 27, 23],
    'day4': [23, 21, 22, 26, 27],
    'day5': [27, 26, 27, 24, 28]
})

# %%
temperatures
# Out:
#         city  day1  day2  day3  day4  day5
# 0   New York    23    22    26    23    27
# 1     London    25    21    25    21    26
# 2      Paris    27    25    24    22    27
# 3     Berlin    26    26    27    26    24
# 4  Amsterdam    24    23    23    27    28

# %%
day1_temps = [23, 25, 27, 26, 24]
temperatures = pd.DataFrame({
    'city': ['New York', 'London', 'Paris', 'Berlin', 'Amsterdam'],
    'day1' : day1_temps,
    'day2' : [22, 21, 25, 26, 23],
    "day3": [26, 25, 24, 27, 23],
    'day4': [23, 21, 22, 26, 27],
    'day5': [27, 26, 27, 24, 28]
})

# %%
temperatures
# Out:
#         city  day1  day2  day3  day4  day5
# 0   New York    23    22    26    23    27
# 1     London    25    21    25    21    26
# 2      Paris    27    25    24    22    27
# 3     Berlin    26    26    27    26    24
# 4  Amsterdam    24    23    23    27    28

# %%
temperatures.melt()
# Out:
#    variable      value
# 0      city   New York
# 1      city     London
# 2      city      Paris
# 3      city     Berlin
# 4      city  Amsterdam
# 5      day1         23
# 6      day1         25
# 7      day1         27
# 8      day1         26
# 9      day1         24
# 10     day2         22
# 11     day2         21
# 12     day2         25
# 13     day2         26
# 14     day2         23
# 15     day3         26
# 16     day3         25
# 17     day3         24
# 18     day3         27
# 19     day3         23
# 20     day4         23
# 21     day4         21
# 22     day4         22
# 23     day4         26
# 24     day4         27
# 25     day5         27
# 26     day5         26
# 27     day5         27
# 28     day5         24
# 29     day5         28

# %%
temperatures.melt(id_vars="city")
# Out:
#          city variable  value
# 0    New York     day1     23
# 1      London     day1     25
# 2       Paris     day1     27
# 3      Berlin     day1     26
# 4   Amsterdam     day1     24
# 5    New York     day2     22
# 6      London     day2     21
# 7       Paris     day2     25
# 8      Berlin     day2     26
# 9   Amsterdam     day2     23
# 10   New York     day3     26
# 11     London     day3     25
# 12      Paris     day3     24
# 13     Berlin     day3     27
# 14  Amsterdam     day3     23
# 15   New York     day4     23
# 16     London     day4     21
# 17      Paris     day4     22
# 18     Berlin     day4     26
# 19  Amsterdam     day4     27
# 20   New York     day5     27
# 21     London     day5     26
# 22      Paris     day5     27
# 23     Berlin     day5     24
# 24  Amsterdam     day5     28

# %%
#temperatures.melt(id_vars=["city", "day1"])
temperatures.melt(id_vars="city", var_name="days", value_name="temperature")
# Out:
#          city  days  temperature
# 0    New York  day1           23
# 1      London  day1           25
# 2       Paris  day1           27
# 3      Berlin  day1           26
# 4   Amsterdam  day1           24
# 5    New York  day2           22
# 6      London  day2           21
# 7       Paris  day2           25
# 8      Berlin  day2           26
# 9   Amsterdam  day2           23
# 10   New York  day3           26
# 11     London  day3           25
# 12      Paris  day3           24
# 13     Berlin  day3           27
# 14  Amsterdam  day3           23
# 15   New York  day4           23
# 16     London  day4           21
# 17      Paris  day4           22
# 18     Berlin  day4           26
# 19  Amsterdam  day4           27
# 20   New York  day5           27
# 21     London  day5           26
# 22      Paris  day5           27
# 23     Berlin  day5           24
# 24  Amsterdam  day5           28

# %%
temperatures.melt(
    id_vars="city", 
    var_name="days", 
    value_name="temperature")
# Out:
#          city  days  temperature
# 0    New York  day1           23
# 1      London  day1           25
# 2       Paris  day1           27
# 3      Berlin  day1           26
# 4   Amsterdam  day1           24
# 5    New York  day2           22
# 6      London  day2           21
# 7       Paris  day2           25
# 8      Berlin  day2           26
# 9   Amsterdam  day2           23
# 10   New York  day3           26
# 11     London  day3           25
# 12      Paris  day3           24
# 13     Berlin  day3           27
# 14  Amsterdam  day3           23
# 15   New York  day4           23
# 16     London  day4           21
# 17      Paris  day4           22
# 18     Berlin  day4           26
# 19  Amsterdam  day4           27
# 20   New York  day5           27
# 21     London  day5           26
# 22      Paris  day5           27
# 23     Berlin  day5           24
# 24  Amsterdam  day5           28

# %%
temperatures.melt(
    id_vars="city", 
    var_name="days", 
    value_name="temperature").head()
# Out:
#         city  days  temperature
# 0   New York  day1           23
# 1     London  day1           25
# 2      Paris  day1           27
# 3     Berlin  day1           26
# 4  Amsterdam  day1           24

# %%
temperatures.melt(
    id_vars="city", 
    var_name="days", 
    value_name="temperature").sample(5)
# Out:
#          city  days  temperature
# 5    New York  day2           22
# 20   New York  day5           27
# 19  Amsterdam  day4           27
# 9   Amsterdam  day2           23
# 21     London  day5           26

# %%
temperatures.melt(
    id_vars="city", 
    var_name="days", 
    value_name="temperature").tail(7)
# Out:
#          city  days  temperature
# 18     Berlin  day4           26
# 19  Amsterdam  day4           27
# 20   New York  day5           27
# 21     London  day5           26
# 22      Paris  day5           27
# 23     Berlin  day5           24
# 24  Amsterdam  day5           28

# %%
stocks = pd.read_csv("prices-split-adjusted.csv",
                    usecols=["date", "symbol", "open", "close"],
                    parse_dates=["date"],
                    index_col="date")

# %%
stocks.head()
# Out:
#            symbol        open       close
# date
# 2016-01-05   WLTW  123.430000  125.839996
# 2016-01-06   WLTW  125.239998  119.980003
# 2016-01-07   WLTW  116.379997  114.949997
# 2016-01-08   WLTW  115.480003  116.620003
# 2016-01-11   WLTW  117.010002  114.970001

# %%
stocks.sample(10)
# Out:
#            symbol        open       close
# date
# 2011-05-11     ED   53.610001   53.689999
# 2010-02-19    HAR   44.029999   43.959999
# 2016-07-12    UPS  110.500000  110.290001
# 2014-09-30    GPN   35.195000   34.939999
# 2014-11-14    TGT   67.330002   68.129997
# 2012-12-12   LVLT   20.700001   21.030001
# 2013-02-15    ALL   45.990002   45.849998
# 2011-03-01    BBT   27.559999   27.020000
# 2015-11-13    DUK   67.449997   66.889999
# 2011-12-28    NFX   37.770000   37.200001

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 851264 entries, 2016-01-05 to 2016-12-30
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   symbol  851264 non-null  object
#  1   open    851264 non-null  float64
#  2   close   851264 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 26.0+ MB

# %%
stocks_small = stocks.loc['2016-02-01': '2016-03-01'].reset_index()

# %%
stocks.loc['2016-02-01': '2016-03-01']
# Out:
#            symbol        open       close
# date
# 2016-02-01   WLTW  114.000000  114.500000
# 2016-02-02   WLTW  113.250000  110.559998
# 2016-02-03   WLTW  113.379997  114.050003
# 2016-02-04   WLTW  114.080002  115.709999
# 2016-02-05   WLTW  115.120003  114.019997
# ...           ...         ...         ...
# 2016-03-01    YUM   52.401151   54.773546
# 2016-03-01    ZBH   97.000000   97.389999
# 2016-03-01   ZION   21.459999   22.309999
# 2016-03-01    ZTS   41.490002   42.099998
# 2016-03-01    AIV   36.910000   37.869999
#
# [10500 rows x 3 columns]

# %%
stocks_small
# Out:
#             date symbol        open       close
# 0     2016-02-01   WLTW  114.000000  114.500000
# 1     2016-02-02   WLTW  113.250000  110.559998
# 2     2016-02-03   WLTW  113.379997  114.050003
# 3     2016-02-04   WLTW  114.080002  115.709999
# 4     2016-02-05   WLTW  115.120003  114.019997
# ...          ...    ...         ...         ...
# 10495 2016-03-01    YUM   52.401151   54.773546
# 10496 2016-03-01    ZBH   97.000000   97.389999
# 10497 2016-03-01   ZION   21.459999   22.309999
# 10498 2016-03-01    ZTS   41.490002   42.099998
# 10499 2016-03-01    AIV   36.910000   37.869999
#
# [10500 rows x 4 columns]

# %%
stocks_small.melt().sample(10)
# Out:
#       variable                value
# 23830     open           105.629997
# 35338    close            88.449997
# 1693      date  2016-02-04 00:00:00
# 14070   symbol                  BBT
# 36329    close            16.790001
# 36146    close            75.230003
# 1739      date  2016-02-04 00:00:00
# 2208      date  2016-02-05 00:00:00
# 2917      date  2016-02-08 00:00:00
# 7014      date  2016-02-22 00:00:00

# %%
stocks_small
# Out:
#             date symbol        open       close
# 0     2016-02-01   WLTW  114.000000  114.500000
# 1     2016-02-02   WLTW  113.250000  110.559998
# 2     2016-02-03   WLTW  113.379997  114.050003
# 3     2016-02-04   WLTW  114.080002  115.709999
# 4     2016-02-05   WLTW  115.120003  114.019997
# ...          ...    ...         ...         ...
# 10495 2016-03-01    YUM   52.401151   54.773546
# 10496 2016-03-01    ZBH   97.000000   97.389999
# 10497 2016-03-01   ZION   21.459999   22.309999
# 10498 2016-03-01    ZTS   41.490002   42.099998
# 10499 2016-03-01    AIV   36.910000   37.869999
#
# [10500 rows x 4 columns]

# %%
stocks.loc['2016-02-01': '2016-03-01'].melt()
# Out:
#       variable      value
# 0       symbol       WLTW
# 1       symbol       WLTW
# 2       symbol       WLTW
# 3       symbol       WLTW
# 4       symbol       WLTW
# ...        ...        ...
# 31495    close  54.773546
# 31496    close  97.389999
# 31497    close  22.309999
# 31498    close  42.099998
# 31499    close  37.869999
#
# [31500 rows x 2 columns]

# %%
display(stocks_small)
# Out:
#             date symbol        open       close
# 0     2016-02-01   WLTW  114.000000  114.500000
# 1     2016-02-02   WLTW  113.250000  110.559998
# 2     2016-02-03   WLTW  113.379997  114.050003
# 3     2016-02-04   WLTW  114.080002  115.709999
# 4     2016-02-05   WLTW  115.120003  114.019997
# ...          ...    ...         ...         ...
# 10495 2016-03-01    YUM   52.401151   54.773546
# 10496 2016-03-01    ZBH   97.000000   97.389999
# 10497 2016-03-01   ZION   21.459999   22.309999
# 10498 2016-03-01    ZTS   41.490002   42.099998
# 10499 2016-03-01    AIV   36.910000   37.869999
#
# [10500 rows x 4 columns]

# %%
stocks_small.pivot(index="symbol", columns="date", values="close")
# Out:
# date    2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# symbol
# A        37.689999   37.070000   37.189999   37.419998   36.040001
# AAL      39.380001   37.029999   37.509998   38.209999   36.750000
# AAP     154.889999  151.860001  147.940002  147.850006  143.940002
# AAPL     96.430000   94.480003   96.349998   96.599998   94.019997
# ABBV     54.389999   53.950001   56.840000   56.759998   53.119999
# ...            ...         ...         ...         ...         ...
# YHOO     29.570000   29.059999   27.680000   29.150000   27.969999
# YUM      52.552121   51.991376   52.084832   51.984185   50.150972
# ZBH      99.029999   98.040001   97.260002   97.550003   95.010002
# ZION     22.500000   21.540001   21.780001   22.049999   21.629999
# ZTS      42.959999   41.720001   41.310001   41.540001   40.910000
#
# date    2016-02-08  2016-02-09  2016-02-10  2016-02-11  2016-02-12  ...  \
# symbol                                                              ...
# ...

# %%
stocks_small.pivot(index="symbol", columns="date", values="close").reset_index()
# Out:
# date symbol  2016-02-01 00:00:00  2016-02-02 00:00:00  2016-02-03 00:00:00  \
# 0         A            37.689999            37.070000            37.189999
# 1       AAL            39.380001            37.029999            37.509998
# 2       AAP           154.889999           151.860001           147.940002
# 3      AAPL            96.430000            94.480003            96.349998
# 4      ABBV            54.389999            53.950001            56.840000
# ..      ...                  ...                  ...                  ...
# 495    YHOO            29.570000            29.059999            27.680000
# 496     YUM            52.552121            51.991376            52.084832
# 497     ZBH            99.029999            98.040001            97.260002
# 498    ZION            22.500000            21.540001            21.780001
# 499     ZTS            42.959999            41.720001            41.310001
#
# ...

# %%
stocks_small.pivot( columns="date", values="close")
# Out:
# date   2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  2016-02-08  \
# 0           114.5         NaN         NaN         NaN         NaN         NaN
# 1             NaN  110.559998         NaN         NaN         NaN         NaN
# 2             NaN         NaN  114.050003         NaN         NaN         NaN
# 3             NaN         NaN         NaN  115.709999         NaN         NaN
# 4             NaN         NaN         NaN         NaN  114.019997         NaN
# ...           ...         ...         ...         ...         ...         ...
# 10495         NaN         NaN         NaN         NaN         NaN         NaN
# 10496         NaN         NaN         NaN         NaN         NaN         NaN
# 10497         NaN         NaN         NaN         NaN         NaN         NaN
# 10498         NaN         NaN         NaN         NaN         NaN         NaN
# 10499         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
ssm = stocks_small.pivot(index="symbol", columns="date", values="close").reset_index()

# %%
#stocks_small.pivot( columns=["symbol", "date"], values="close").reset_index()

# %%
ssm.head()
# Out:
# date symbol  2016-02-01 00:00:00  2016-02-02 00:00:00  2016-02-03 00:00:00  \
# 0         A            37.689999            37.070000            37.189999
# 1       AAL            39.380001            37.029999            37.509998
# 2       AAP           154.889999           151.860001           147.940002
# 3      AAPL            96.430000            94.480003            96.349998
# 4      ABBV            54.389999            53.950001            56.840000
#
# date  2016-02-04 00:00:00  2016-02-05 00:00:00  2016-02-08 00:00:00  \
# 0               37.419998            36.040001            34.799999
# 1               38.209999            36.750000            35.549999
# 2              147.850006           143.940002           141.449997
# 3               96.599998            94.019997            95.010002
# 4               56.759998            53.119999            52.889999
#
# date  2016-02-09 00:00:00  2016-02-10 00:00:00  2016-02-11 00:00:00  ...  \
# ...

# %%
str(stocks_small['date'][0])
# Out:
# '2016-02-01 00:00:00'

# %%
ssm = stocks_small.pivot(index="symbol", columns="date", values="close")

# %%
ssm
# Out:
# date    2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# symbol
# A        37.689999   37.070000   37.189999   37.419998   36.040001
# AAL      39.380001   37.029999   37.509998   38.209999   36.750000
# AAP     154.889999  151.860001  147.940002  147.850006  143.940002
# AAPL     96.430000   94.480003   96.349998   96.599998   94.019997
# ABBV     54.389999   53.950001   56.840000   56.759998   53.119999
# ...            ...         ...         ...         ...         ...
# YHOO     29.570000   29.059999   27.680000   29.150000   27.969999
# YUM      52.552121   51.991376   52.084832   51.984185   50.150972
# ZBH      99.029999   98.040001   97.260002   97.550003   95.010002
# ZION     22.500000   21.540001   21.780001   22.049999   21.629999
# ZTS      42.959999   41.720001   41.310001   41.540001   40.910000
#
# date    2016-02-08  2016-02-09  2016-02-10  2016-02-11  2016-02-12  ...  \
# symbol                                                              ...
# ...

# %%
temperatures
# Out:
#         city  day1  day2  day3  day4  day5
# 0   New York    23    22    26    23    27
# 1     London    25    21    25    21    26
# 2      Paris    27    25    24    22    27
# 3     Berlin    26    26    27    26    24
# 4  Amsterdam    24    23    23    27    28

# %%
temperatures.pivot(index="city", columns="day1")
# Out:
#            day2                          day3                          day4  \
# day1         23    24    25    26    27    23    24    25    26    27    23
# city
# Amsterdam   NaN  23.0   NaN   NaN   NaN   NaN  23.0   NaN   NaN   NaN   NaN
# Berlin      NaN   NaN   NaN  26.0   NaN   NaN   NaN   NaN  27.0   NaN   NaN
# London      NaN   NaN  21.0   NaN   NaN   NaN   NaN  25.0   NaN   NaN   NaN
# New York   22.0   NaN   NaN   NaN   NaN  26.0   NaN   NaN   NaN   NaN  23.0
# Paris       NaN   NaN   NaN   NaN  25.0   NaN   NaN   NaN   NaN  24.0   NaN
#
#                                    day5
# day1         24    25    26    27    23    24    25    26    27
# city
# Amsterdam  27.0   NaN   NaN   NaN   NaN  28.0   NaN   NaN   NaN
# Berlin      NaN   NaN  26.0   NaN   NaN   NaN   NaN  24.0   NaN
# London      NaN  21.0   NaN   NaN   NaN   NaN  26.0   NaN   NaN
# New York    NaN   NaN   NaN   NaN  27.0   NaN   NaN   NaN   NaN
# ...

# %%
temperatures2 = pd.DataFrame({
    'city': ['New York', 'London', 'Paris', 'Berlin', 'Amsterdam', 'New York'],
    'day1' : [23, 25, 27, 26, 24, 22],
    'day2' : [22, 21, 25, 26, 23, 21],
    "day3": [26, 25, 24, 27, 23, 23],
    'day4': [23, 21, 22, 26, 27, 22],
    'day5': [27, 26, 27, 24, 28, 22]
})

# %%
temperatures2
# Out:
#         city  day1  day2  day3  day4  day5
# 0   New York    23    22    26    23    27
# 1     London    25    21    25    21    26
# 2      Paris    27    25    24    22    27
# 3     Berlin    26    26    27    26    24
# 4  Amsterdam    24    23    23    27    28
# 5   New York    22    21    23    22    22

# %%
temperatures2.pivot(index="city", columns="day1")
# Out:
#            day2                                day3                    ...  \
# day1         22    23    24    25    26    27    22    23    24    25  ...
# city                                                                   ...
# Amsterdam   NaN   NaN  23.0   NaN   NaN   NaN   NaN   NaN  23.0   NaN  ...
# Berlin      NaN   NaN   NaN   NaN  26.0   NaN   NaN   NaN   NaN   NaN  ...
# London      NaN   NaN   NaN  21.0   NaN   NaN   NaN   NaN   NaN  25.0  ...
# New York   21.0  22.0   NaN   NaN   NaN   NaN  23.0  26.0   NaN   NaN  ...
# Paris       NaN   NaN   NaN   NaN   NaN  25.0   NaN   NaN   NaN   NaN  ...
#
#            day4                    day5
# day1         24    25    26    27    22    23    24    25    26    27
# city
# Amsterdam  27.0   NaN   NaN   NaN   NaN   NaN  28.0   NaN   NaN   NaN
# Berlin      NaN   NaN  26.0   NaN   NaN   NaN   NaN   NaN  24.0   NaN
# London      NaN  21.0   NaN   NaN   NaN   NaN   NaN  26.0   NaN   NaN
# ...

# %%
stocks_small
# Out:
#             date symbol        open       close
# 0     2016-02-01   WLTW  114.000000  114.500000
# 1     2016-02-02   WLTW  113.250000  110.559998
# 2     2016-02-03   WLTW  113.379997  114.050003
# 3     2016-02-04   WLTW  114.080002  115.709999
# 4     2016-02-05   WLTW  115.120003  114.019997
# ...          ...    ...         ...         ...
# 10495 2016-03-01    YUM   52.401151   54.773546
# 10496 2016-03-01    ZBH   97.000000   97.389999
# 10497 2016-03-01   ZION   21.459999   22.309999
# 10498 2016-03-01    ZTS   41.490002   42.099998
# 10499 2016-03-01    AIV   36.910000   37.869999
#
# [10500 rows x 4 columns]

# %%
ssm
# Out:
# date    2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# symbol
# A        37.689999   37.070000   37.189999   37.419998   36.040001
# AAL      39.380001   37.029999   37.509998   38.209999   36.750000
# AAP     154.889999  151.860001  147.940002  147.850006  143.940002
# AAPL     96.430000   94.480003   96.349998   96.599998   94.019997
# ABBV     54.389999   53.950001   56.840000   56.759998   53.119999
# ...            ...         ...         ...         ...         ...
# YHOO     29.570000   29.059999   27.680000   29.150000   27.969999
# YUM      52.552121   51.991376   52.084832   51.984185   50.150972
# ZBH      99.029999   98.040001   97.260002   97.550003   95.010002
# ZION     22.500000   21.540001   21.780001   22.049999   21.629999
# ZTS      42.959999   41.720001   41.310001   41.540001   40.910000
#
# date    2016-02-08  2016-02-09  2016-02-10  2016-02-11  2016-02-12  ...  \
# symbol                                                              ...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'A'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [107], in <cell line: 1>()
# ----> 1 stocks_small.loc("A")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:634, in _LocationIndexer.__call__(self, axis)
#     631 new_self = type(self)(self.name, self.obj)
#     633 if axis is not None:
# --> 634     axis = self.obj._get_axis_number(axis)
#     635 new_self.axis = axis
#     636 return new_self
#
# ...

# %%
pivot1 = stocks_small.pivot(index="symbol", columns="date")

# %%
pivot1.head()
# Out:
#               open                                                  \
# date    2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05
# symbol
# A        37.369999   37.180000   37.270000   37.150002   37.259998
# AAL      39.000000   38.830002   37.380001   37.340000   37.709999
# AAP     151.699997  154.380005  151.580002  147.460007  147.539993
# AAPL     96.470001   95.419998   95.000000   95.860001   96.519997
# ABBV     54.160000   53.639999   54.529999   56.740002   56.250000
#
#                                                                     ...  \
# date    2016-02-08  2016-02-09  2016-02-10  2016-02-11  2016-02-12  ...
# symbol                                                              ...
# A        35.610001   34.209999   35.630001   35.119999   35.840000  ...
# AAL      36.080002   34.930000   36.570000   36.470001   36.919998  ...
# AAP     142.770004  141.149994  141.130005  137.039993  139.539993  ...
# ...

# %%
pivot1['open']['2016-02-01']
# Out:
# symbol
# A        37.369999
# AAL      39.000000
# AAP     151.699997
# AAPL     96.470001
# ABBV     54.160000
#            ...
# YHOO     29.270000
# YUM      51.703813
# ZBH      98.279999
# ZION     22.549999
# ZTS      43.000000
# Name: 2016-02-01 00:00:00, Length: 500, dtype: float64

# %%
pivot2 = stocks_small.pivot(index="symbol", columns="date", values="close")

# %%
pivot2.head()
# Out:
# date    2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# symbol
# A        37.689999   37.070000   37.189999   37.419998   36.040001
# AAL      39.380001   37.029999   37.509998   38.209999   36.750000
# AAP     154.889999  151.860001  147.940002  147.850006  143.940002
# AAPL     96.430000   94.480003   96.349998   96.599998   94.019997
# ABBV     54.389999   53.950001   56.840000   56.759998   53.119999
#
# date    2016-02-08  2016-02-09  2016-02-10  2016-02-11  2016-02-12  ...  \
# symbol                                                              ...
# A        34.799999   35.369999   35.849998   35.330002   36.220001  ...
# AAL      35.549999   36.189999   37.119999   36.490002   37.820000  ...
# AAP     141.449997  141.500000  138.570007  138.410004  140.770004  ...
# AAPL     95.010002   94.989998   94.269997   93.699997   93.989998  ...
# ABBV     52.889999   53.480000   52.720001   52.180000   52.580002  ...
#
# ...

# %%
pivot1.close.head()
# Out:
# date    2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# symbol
# A        37.689999   37.070000   37.189999   37.419998   36.040001
# AAL      39.380001   37.029999   37.509998   38.209999   36.750000
# AAP     154.889999  151.860001  147.940002  147.850006  143.940002
# AAPL     96.430000   94.480003   96.349998   96.599998   94.019997
# ABBV     54.389999   53.950001   56.840000   56.759998   53.119999
#
# date    2016-02-08  2016-02-09  2016-02-10  2016-02-11  2016-02-12  ...  \
# symbol                                                              ...
# A        34.799999   35.369999   35.849998   35.330002   36.220001  ...
# AAL      35.549999   36.189999   37.119999   36.490002   37.820000  ...
# AAP     141.449997  141.500000  138.570007  138.410004  140.770004  ...
# AAPL     95.010002   94.989998   94.269997   93.699997   93.989998  ...
# ABBV     52.889999   53.480000   52.720001   52.180000   52.580002  ...
#
# ...

# %%
pivot1['close'].head()
# Out:
# date    2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# symbol
# A        37.689999   37.070000   37.189999   37.419998   36.040001
# AAL      39.380001   37.029999   37.509998   38.209999   36.750000
# AAP     154.889999  151.860001  147.940002  147.850006  143.940002
# AAPL     96.430000   94.480003   96.349998   96.599998   94.019997
# ABBV     54.389999   53.950001   56.840000   56.759998   53.119999
#
# date    2016-02-08  2016-02-09  2016-02-10  2016-02-11  2016-02-12  ...  \
# symbol                                                              ...
# A        34.799999   35.369999   35.849998   35.330002   36.220001  ...
# AAL      35.549999   36.189999   37.119999   36.490002   37.820000  ...
# AAP     141.449997  141.500000  138.570007  138.410004  140.770004  ...
# AAPL     95.010002   94.989998   94.269997   93.699997   93.989998  ...
# ABBV     52.889999   53.480000   52.720001   52.180000   52.580002  ...
#
# ...

# %% [markdown]
# ## Exercise
# Make a dataframe with the dates as the rows, the symbols as the columns and the opening prices as the values

# %%
# previous code:
# stocks_small.pivot(index="symbol", columns="date", values="close")

# %%
temperatures
# Out:
#         city  day1  day2  day3  day4  day5
# 0   New York    23    22    26    23    27
# 1     London    25    21    25    21    26
# 2      Paris    27    25    24    22    27
# 3     Berlin    26    26    27    26    24
# 4  Amsterdam    24    23    23    27    28

# %%
dft = temperatures.melt(
    id_vars="city", 
    var_name="days", 
    value_name="temperature")

# %%
dft.set_index('city')
# Out:
#            days  temperature
# city
# New York   day1           23
# London     day1           25
# Paris      day1           27
# Berlin     day1           26
# Amsterdam  day1           24
# New York   day2           22
# London     day2           21
# Paris      day2           25
# Berlin     day2           26
# Amsterdam  day2           23
# New York   day3           26
# London     day3           25
# Paris      day3           24
# Berlin     day3           27
# Amsterdam  day3           23
# New York   day4           23
# London     day4           21
# Paris      day4           22
# Berlin     day4           26
# Amsterdam  day4           27
# New York   day5           27
# London     day5           26
# Paris      day5           27
# Berlin     day5           24
# Amsterdam  day5           28

# %%
dft.pivot(index='city', columns='days', values='temperature').reset_index()
# Out:
# days       city  day1  day2  day3  day4  day5
# 0     Amsterdam    24    23    23    27    28
# 1        Berlin    26    26    27    26    24
# 2        London    25    21    25    21    26
# 3      New York    23    22    26    23    27
# 4         Paris    27    25    24    22    27

# %%
temperatures.sort_values('city')
# Out:
#         city  day1  day2  day3  day4  day5
# 4  Amsterdam    24    23    23    27    28
# 3     Berlin    26    26    27    26    24
# 1     London    25    21    25    21    26
# 0   New York    23    22    26    23    27
# 2      Paris    27    25    24    22    27
