# %%
from dotenv import dotenv_values

config = dotenv_values(".env")

import requests
import json

bearer_token = config["BEARER_TOKEN"]

search_url = "https://api.twitter.com/2/tweets/search/recent"

query_params = {
    # Escaping the character \"
    'query' : "\"World Cup\" Brazil  ",
    'query' : '"World Cup" Brazil Argentina Ice-Cream',
    'max_results' : '25',
    'tweet.fields': 'author_id',
    'user.fields': 'name',
    'next_token': 'b26v89c19zqg8o3fqk10eyhw41g8yc9g7cvhlrf4yzwxp'
}

def bearer_oauth(r):
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    #response.status_code
    # 200 is good
    # everything else is an error
    # 404 page not found
    return response.json()

json_response = connect_to_endpoint(search_url, query_params)

parsedRes = json.dumps(json_response, indent=4, ensure_ascii=False)
print(parsedRes)
# Out:
# {
#     "data": [
#         {
#             "text": "Brazil   loses their bid for a FIFA World Cup in 3000",
#             "edit_history_tweet_ids": [
#                 "1602411900758695936"
#             ],
#             "author_id": "1281127955134066688",
#             "id": "1602411900758695936"
#         },
#         {
#             "text": "@AG_Smithy Sven losing just 2 to Brazil and France in itself is superior to Southgate losing 3 in one World Cup alone to Belgium and Croatia!",
#             "edit_history_tweet_ids": [
#                 "1602411003043610624"
#             ],
#             "author_id": "2306107419",
#             "id": "1602411003043610624"
#         },
#         {
#             "text": "Dominik Livakovič vs Brazil - 2022 FIFA World Cup https://t.co/87ShwOOABG",
#             "edit_history_tweet_ids": [
#                 "1602410700978401280"
#             ],
#             "author_id": "1106818991585193985",
#             "id": "1602410700978401280"
# ...

# %%
json_response['data'][0]['text']
# Out:
# 'Brazil   loses their bid for a FIFA World Cup in 3000'

# %%
type(json_response['data'][0]['text'])
# Out:
# str
