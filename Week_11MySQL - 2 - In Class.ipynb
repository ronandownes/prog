# %%
# !pip install sqlalchemy
# !pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import sqlalchemy
import pymysql

# %%
user = "pda2022"
password = "pda2022"
# database = test

sqlEngine = sqlalchemy.create_engine(f"mysql+pymysql://{user}:{password}@localhost/")
conn = sqlEngine.connect()

# %%
print(conn)

# %%
conn.execute("CREATE DATABASE testDB;")

# %%
conn.execute("USE testDB;")

# %%
df = pd.DataFrame({'col1': [1, 2, 3], 'col2': [4, 5, 6]})

# %%
df
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
#conn.close()

# %%
df.to_sql("test2", conn, index=False)
# Out:
# 3

# %%
res = conn.execute("SELECT * FROM test2;")

# %%
res.keys()
# Out:
# RMKeyView(['col1', 'col2'])

# %%
for i in res:
    print(i)
# Out:
# (1, 4)
# (2, 5)
# (3, 6)

# %%
df2 = pd.read_sql("SELECT * FROM test;", conn)

# %%
df2.drop(columns="index")
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
data = pd.read_csv("General Electric(1).csv")

# %%
data.to_sql("GE3;", conn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 data.to_sql("GE3;", conn)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# ...

# %%
pd.read_sql("SELECT * FROM GE;", conn)
# Out:
#     Year           Company  Revenue (in millions)  Profit (in millions)
# 0   1955  General Electric                 2959.1                 212.6
# 1   1956  General Electric                 3095.4                 200.9
# 2   1957  General Electric                 4090.0                 213.8
# 3   1958  General Electric                 4335.7                 247.9
# 4   1959  General Electric                 4120.8                 242.9
# 5   1960  General Electric                 4349.5                 280.2
# 6   1961  General Electric                 4197.5                 200.1
# 7   1962  General Electric                 4456.8                 242.1
# 8   1963  General Electric                 4792.7                 265.8
# 9   1964  General Electric                 4918.7                 270.6
# 10  1965  General Electric                 4941.4                 237.3
# 11  1966  General Electric                 6213.6                 355.1
# ...

# %%
data
# Out:
#     Year           Company  Revenue (in millions)  Profit (in millions)
# 0   1955  General Electric                 2959.1                 212.6
# 1   1956  General Electric                 3095.4                 200.9
# 2   1957  General Electric                 4090.0                 213.8
# 3   1958  General Electric                 4335.7                 247.9
# 4   1959  General Electric                 4120.8                 242.9
# 5   1960  General Electric                 4349.5                 280.2
# 6   1961  General Electric                 4197.5                 200.1
# 7   1962  General Electric                 4456.8                 242.1
# 8   1963  General Electric                 4792.7                 265.8
# 9   1964  General Electric                 4918.7                 270.6
# 10  1965  General Electric                 4941.4                 237.3
# 11  1966  General Electric                 6213.6                 355.1
# ...
